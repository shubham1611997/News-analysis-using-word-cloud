# %%
from PIL import Image,ImageOps,ImageDraw,ImageFont
from nltk.tokenize import sent_tokenize , word_tokenize
from collections import Counter
from nltk.corpus import wordnet
from bs4 import BeautifulSoup
from nltk import FreqDist
import numpy as np
import random
import urllib

# %%
quote_page = "http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html"
page = urllib.request.urlopen(quote_page)

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/NewsArticle" lang="en">
#  <head>
#   <meta content="S33.80" name="eomportal-instanceid"/>
#   <meta content="433656" name="eomportal-id"/>
#   <meta content="1.6.393534129" name="eomportal-loid"/>
#   <meta content="07bfa1d0-870b-11e7-b7bc-fa1568cb40f1" name="eomportal-uuid"/>
#   <meta content="Tue Nov 14 01:03:55 IST 2017" name="eomportal-lastUpdate"/>
#   <script src="http://www.hindustantimes.com/res/js/jquery-1.11.0.min.js" type="text/javascript">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    var _sf_startpt=(new Date()).getTime()
#   </script>
#   <meta content="width=1325" name="viewport"/>
#   <link href="http://www.hindustantimes.com/favicon.ico" rel="icon"/>
#   <link href="http://www.hindustantimes.com/res/css-ns/combine.css?v=1" rel="stylesheet"/>
#   <link href="http://www.hindustantimes.com/res/css-ns/style.css?v1=9" rel="stylesheet"/>
#   <script type="text/javascript">
#    var _comscore = _comscore || []; _comscore.push({ c1: "2", c2: "6035286" }); (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#   </script>
#   <noscript>
#    <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035286&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- End comScore Tag -->
#   <script>
#    dataLayer = [ {
# 				"byline" : "Namita Bhandare",
# 				"section" : "opinion/analysis",
# 				"contributor" : "aasheesh.sharma",
# 				"pubtime" : "08222017-13:32:27",
# 				"storytags" : "Instant triple talaq, Triple talaq, Unislamic, Supreme Court, Shah Bano, Rajiv Gandhi, Parliament, Bharatiya Mahila Muslim Andolan"
# 			} ];
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KSLPR3B');
#   </script>
#   <meta content="100006810078735" property="fb:admins">
#    <meta content="672336366190593" property="fb:app_id">
#     <meta content="http://www.hindustantimes.com/" property="og:site_name">
#      <meta charset="utf-8"/>
#      <meta content="IE=9;IE=10;IE=11" http-equiv="X-UA-Compatible"/>
#      <meta content="Tuesday 22 August 2017, 17:29:03 PM" http-equiv="Last-Modified"/>
#      <meta content="analysis" itemprop="articleSection" name="section"/>
#      <script id="liftigniter-metadata" type="application/json">
#       { "image" : "http://www.hindustantimes.com/rf/image_size_90x90/HT/p2/2017/08/22/Pictures/farha-faiz_437ec5ea-8731-11e7-a194-d8b7abb7611c.jpg"}
#      </script>
#      <meta content="article" property="og:type">
#       <title>
#        Instant triple talaq: Supreme Court verdict is a landmark for gender justice | analysis | Hindustan Times
#       </title>
#       <meta content="English" itemprop="inLanguage"/>
#       <meta content="In the 31 years since the passing of the Muslim Women (Protection of Rights under Divorce) Act , the Supreme Court has consistently batted for the rights of minority women" itemprop="description" name="Description">
#        <meta content="Instant triple talaq, Triple talaq, Unislamic, Supreme Court, Shah Bano, Rajiv Gandhi, Parliament, Bharatiya Mahila Muslim Andolan" itemprop="keywords" name="keywords"/>
#        <meta content="Instant triple talaq, Triple talaq, Unislamic, Supreme Court, Shah Bano, Rajiv Gandhi, Parliament, Bharatiya Mahila Muslim Andolan" name="news_keywords"/>
#        <link href="http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html" itemprop="mainEntityOfPage" rel="canonical"/>
#        <link href="http://m.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html" media="only screen and (maxwidth:640px)" rel="alternate">
#         <link href="http://m.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI_amp.html" rel="amphtml"/>
#         <link href="http://m.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html" media="handheld" rel="alternate">
#          <meta content="Instant triple talaq: Supreme Court verdict is a landmark for gender justice" property="og:title"/>
#          <meta content="http://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2017/08/22/Pictures/farha-faiz_3ecef290-8731-11e7-a194-d8b7abb7611c.jpg" property="og:image"/>
#          <meta content="In the 31 years since the passing of the Muslim Women (Protection of Rights under Divorce) Act , the Supreme Court has consistently batted for the rights of minority women" property="og:description"/>
#          <meta content="http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html" property="og:url"/>
#          <meta content="Instant triple talaq: Supreme Court verdict is a landmark for gender justice" name="tweetmeme-title"/>
#          <link href="http://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2017/08/22/Pictures/farha-faiz_3ecef290-8731-11e7-a194-d8b7abb7611c.jpg" rel="image_src">
#           <meta content="summary_large_image" name="twitter:card"/>
#           <meta content="@httweets" name="twitter:site"/>
#           <meta content="hindustantimes.com" name="twitter:domain"/>
#           <meta content="http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html" name="twitter:url"/>
#           <meta content="Instant triple talaq: Supreme Court verdict is a landmark for gender justice" name="twitter:title"/>
#           <meta content="In the 31 years since the passing of the Muslim Women (Protection of Rights under Divorce) Act , the Supreme Court has consistently batted for the rights of minority women" name="twitter:description"/>
#           <meta content="http://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2017/08/22/Pictures/farha-faiz_3ecef290-8731-11e7-a194-d8b7abb7611c.jpg" name="twitter:image"/>
#           <meta content="2017-08-22T13:32Z" property="article:published_time"/>
#           <script type="text/javascript">
#            (function () {
#     var d = new Image(1,1);
#     d.onerror = d.onload = function () { d.onerror = d.onload = null;};
#     d.src = ["//secure-gl.imrworldwide.com/cgi-bin/m?ci=ent1236951067&am=3&ep=1&at=view&rt=banner&st=image&ca=cmp238091&cr=crv1292219&pc=plc25256514&r=", (new Date()).getTime()].join('');
#   })();
#           </script>
#           <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#           </script>
#           <script>
#            var googletag = googletag || {};googletag.cmd = googletag.cmd || [];
#           </script>
#           <script type="text/javascript">
#            googletag.cmd.push(function() {
#
# 	googletag.defineSlot('/1055314/HT_StoryPages_300x250_Bottom',[300, 250],'div-gpt-ad-1463375425115-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
# 	googletag.defineSlot('/1055314/HT_StoryPages_300x250_Middle',[300, 250],'div-gpt-ad-1463375425115-1').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
# 	googletag.defineSlot('/1055314/HT_StoryPages_300x250_Top',[300, 250],'div-gpt-ad-1463375425115-2').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
# 	googletag.defineSlot('/1055314/HT_StoryPages_728x90_Bottom',[728, 90],'div-gpt-ad-1507722767286-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
# 	googletag.defineSlot('/1055314/HT_StoryPages_728x90_Top',[728, 90],'div-gpt-ad-1463375425115-3').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
# 	googletag.defineSlot('/1055314/HT_StoryPage_Overlay_1x1',[1, 1],'div-gpt-ad-1479816707506-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
# 	googletag.defineSlot('/1055314/HT_StoryPage_Billboard_1290x50',[1290, 50],'div-gpt-ad-1479816299356-2').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
#
# googletag.pubads().setTargeting('section','opinion');
# googletag.pubads().setTargeting('subsection','analysis');
# googletag.pubads().setTargeting('page_url', 'instant-triple');
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
#           </script>
#           <style type="text/css">
#            #zzheader1487748206 a img{width:0px};
#           </style>
#           <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#           <!--[if lt IE 9]> <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script> <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>   <![endif]-->
#           <!--[if gte IE 9]> <link href="http://www.hindustantimes.com/res/css-ns/ie9.css" rel="stylesheet">  <![endif]-->
#           <script type="text/javascript">
#            window._taboola = window._taboola || [];
#   _taboola.push({'article':'auto'});
#   !function (e, f, u, i) {
#     if (!document.getElementById(i)){
#       e.async = 1;
#       e.src = u;
#       e.id = i;
#       f.parentNode.insertBefore(e, f);
#     }
#   }(document.createElement('script'),
#   document.getElementsByTagName('script')[0],
#   '//cdn.taboola.com/libtrc/htmedialtd-hindustantimescom/loader.js',
#   'tb_loader_script');
#   if(window.performance && typeof window.performance.mark == 'function')
#     {window.performance.mark('tbl_ic');}
#           </script>
#          </link>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body autofocus="">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KSLPR3B" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="main-wrapper">
#    <header class="header-wrapper">
#     <section class="top-header">
#      <div class="container">
#       <div class="row">
#        <div class="col-md-6 col-lg-5">
#         <div class="header-logo">
#          <a href="http://www.hindustantimes.com/">
#           <img alt="Logo" src="http://www.hindustantimes.com/images/app-images/ht/logo-big-cm.png"/>
#          </a>
#         </div>
#         <ul class="top-nav-option">
#          <li>
#           <div class="nav-opt-info">
#            <i aria-hidden="true" class="fa fa-newspaper-o">
#            </i>
#            <a href="http://paper.hindustantimes.com/epaper/viewer.aspx">
#             e-paper
#            </a>
#           </div>
#          </li>
#          <li>
#           <div class="weather-drop">
#            <div id="weather">
#            </div>
#            <span>
#             India
#            </span>
#            <span class="arrow-ico icons">
#            </span>
#           </div>
#          </li>
#          <li class="follow-bx">
#           <span>
#            Follow us:
#           </span>
#           <a href="https://twitter.com/htTweets" target="_blank">
#            <i aria-hidden="true" class="fa fa-twitter fa-top-hm">
#            </i>
#           </a>
#           <a href="https://www.facebook.com/hindustantimes" target="_blank">
#            <i aria-hidden="true" class="fa fa-facebook fa-top-hm">
#            </i>
#           </a>
#           <a href="https://plus.google.com/+hindustantimes/posts" target="_blank">
#            <i aria-hidden="true" class="fa fa-google-plus fa-top-hm">
#            </i>
#           </a>
#           <a href="https://www.instagram.com/hindustantimes/" target="_blank">
#            <i aria-hidden="true" class="fa fa-instagram fa-top-hm">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-6 col-lg-7">
#         <div class="advertisement-area">
#          <div id="div-gpt-ad-1463375425115-3">
#           <script type="text/javascript">
#            googletag.cmd.push(function() {googletag.display('div-gpt-ad-1463375425115-3');});
#           </script>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="weather-area">
#        <div class="row">
#         <div class="col-sm-12 col-md-4 col-lg-3">
#          <div class="weather-details">
#           <div class="headingfour">
#            <span>
#             Today in
#            </span>
#            <span id="cname">
#             <span id="MCity">
#              New Delhi
#             </span>
#            </span>
#            <span>
#             , India
#            </span>
#           </div>
#           <div>
#            <span>
#             Nov 14, 2017-Tuesday
#            </span>
#           </div>
#           <div id="weather_dt">
#            <div class="inner-headingtwo">
#             <span id="MTemp">
#              -
#             </span>
#             °C
#            </div>
#            <span id="WCity">
#             New Delhi
#            </span>
#           </div>
#           <ul class="humidity-dt row">
#            <li class="col-sm-3 col-md-6">
#             Humidity
#             <div id="chumidity">
#              -
#             </div>
#            </li>
#            <li class="col-sm-3 col-md-6">
#             Wind
#             <div id="cwind">
#              -
#             </div>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="col-sm-12 col-md-8 col-lg-9">
#          <div class="change-city">
#           <div class="headingfour">
#            select city
#           </div>
#           <ul class="change-city-list">
#            <li>
#             <span>
#              Metro cities -
#             </span>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('New Delhi');">
#              Delhi
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Mumbai');">
#              Mumbai
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Chennai');">
#              Chennai
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Kolkata');">
#              Kolkata
#             </a>
#            </li>
#           </ul>
#           <ul class="change-city-list">
#            <li>
#             <span>
#              Other cities -
#             </span>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Noida');">
#              Noida
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Gurgaon');">
#              Gurgaon
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Bengaluru');">
#              Bengaluru
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Hyderabad');">
#              Hyderabad
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Bhopal');">
#              Bhopal
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Chandigarh');">
#              Chandigarh
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Dehradun');">
#              Dehradun
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Indore');">
#              Indore
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Jaipur');">
#              Jaipur
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Lucknow');">
#              Lucknow
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Patna');">
#              Patna
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="return weatherAPI('Ranchi');">
#              Ranchi
#             </a>
#            </li>
#           </ul>
#           <div class="weather-source">
#            <span>
#             Powered by
#            </span>
#            <img src="http://www.hindustantimes.com/images/app-images/ht/source_weather-cm.png"/>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div id="divAll" style="display:none;">
#       </div>
#      </div>
#     </section>
#     <section class="header-menu">
#      <div class="container">
#       <div class="main-nav clearfix">
#        <div class="mobile-icon">
#         <a class="hamburger" href="javascript:void(0)">
#          <i class="icons hamburger-icon">
#          </i>
#         </a>
#         <a class="logo-img" href="http://www.hindustantimes.com/">
#          <img alt="HT Logo" src="http://www.hindustantimes.com/images/app-images/ht/sm-logo-cm.png"/>
#         </a>
#        </div>
#        <div class="nav-area">
#         <ul class="menu-list clearfix" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
#          <li class="close-btn clearfix">
#           <a href="javascript:void(0)">
#            <i class="icons back-icons">
#            </i>
#            Close
#           </a>
#          </li>
#          <li class="india-col" itemprop="name">
#           <a href=" /india-news/" id="amenu-india-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'india'})">
#            india
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_india">
#           </div>
#          </li>
#          <li class="world-col" itemprop="name">
#           <a href=" /world-news/" id="amenu-world-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'world'})">
#            world
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_world">
#           </div>
#          </li>
#          <li class="cities-col">
#           <a id="amenu-cities-col" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'cities'})">
#            cities
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_city">
#           </div>
#          </li>
#          <li class="opinion-col" itemprop="name">
#           <a href=" /opinion/" id="amenu-opinion-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'opinion'})">
#            opinion
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_opinion">
#           </div>
#          </li>
#          <li class="sports-col" itemprop="name">
#           <a href=" /sports-news/" id="amenu-sports-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'sports'})">
#            sports
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_sports">
#           </div>
#          </li>
#          <li class="entertainment-col" itemprop="name">
#           <a href=" /entertainment/" id="amenu-entertainment-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'entertainment'})">
#            entertainment
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_entertainment">
#           </div>
#          </li>
#          <li class="lifestyle-col" itemprop="name">
#           <a href=" /lifestyle/" id="amenu-lifestyle-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'lifestyle'})">
#            lifestyle
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_lifestyle">
#           </div>
#          </li>
#          <li class="business-col" itemprop="name">
#           <a href=" /business-news/" id="amenu-business-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'business'})">
#            business
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="business_tech">
#           </div>
#          </li>
#          <li class="tech-col" itemprop="name">
#           <a href=" /tech/" id="amenu-tech-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'tech'})">
#            tech
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_tech">
#           </div>
#          </li>
#          <li class="education-col" itemprop="name">
#           <a href=" /education/" id="amenu-education-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'education'})">
#            education
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_education">
#           </div>
#          </li>
#          <li class="what-now-col" itemprop="name">
#           <a href=" /what-now/" id="amenu-what-now-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'whatnow'})">
#            whatnow
#           </a>
#           <span class="line-slide">
#           </span>
#          </li>
#          <li class="photos-col" itemprop="name">
#           <a href=" /photos/" id="amenu-photos-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'photos'})">
#            photos
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_photos">
#           </div>
#          </li>
#          <li class="videos-col" itemprop="name">
#           <a href=" /videos/" id="amenu-videos-col" itemprop="url" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L1', 'label': 'videos'})">
#            videos
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_videos">
#           </div>
#          </li>
#          <li class="more-opt">
#           <a class="" href="javascript:void(0)">
#            <img alt="" src="http://www.hindustantimes.com/images/app-images/ht/more-icon-cm.png"/>
#           </a>
#           <span class="line-slide">
#           </span>
#           <span class="icon-plus icon">
#            <i class="icons plus-icons">
#            </i>
#           </span>
#           <div class="ns-megamenu" id="menu_more">
#           </div>
#          </li>
#         </ul>
#        </div>
#        <ul class="menu-tool-pnl">
#         <li>
#          <a class="search-btn" href="javascript:void(0)" id="anchorSearch" onclick="SubmitMyForm();">
#           <i aria-hidden="true" class="fa fa-search fa-search">
#           </i>
#          </a>
#         </li>
#         <li class="dropdown">
#          <a aria-expanded="false" aria-haspopup="true" data-target="#" data-toggle="dropdown" href="#" id="dLabel" role="button">
#           <i class="icons more-tool-ico">
#           </i>
#          </a>
#          <ul aria-labelledby="dLabel" class="dropdown-menu client-opt right row">
#           <li>
#            <a href="http://www.livemint.com/" target="_blank">
#             Livemint
#            </a>
#           </li>
#           <li>
#            <a href="http://www.livehindustan.com/" target="_blank">
#             Livehindustan
#            </a>
#           </li>
#           <li>
#            <a href="http://www.shine.com/" target="_blank">
#             Shine
#            </a>
#           </li>
#           <li>
#            <a href="http://www.htcampus.com/" target="_blank">
#             HTcampus
#            </a>
#           </li>
#           <li>
#            <a href="http://www.mycollegesabroad.com/" target="_blank">
#             Mycollegesabroad
#            </a>
#           </li>
#           <li>
#            <a href="http://www.desimartini.com/" target="_blank">
#             Desimartini
#            </a>
#           </li>
#           <li>
#            <a href="http://www.studymateonline.com/" target="_blank">
#             Studymate
#            </a>
#           </li>
#           <li>
#            <a href="http://www.englishmate.com/" target="_blank">
#             Englishmate
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#        <form id="searchForm" method="post">
#         <!-- <input name="id" type="hidden" value="advancedSearch">  -->
#         <input class="search-pnl" id="newsearchbox_new" name="search" placeholder="Search" required="required" type="text" value=""/>
#        </form>
#        <script>
#         function SubmitMyForm() {var txtSearchValue=document.getElementById("newsearchbox_new").value; if (txtSearchValue != "" && txtSearchValue != null) {var finalSearchKeywords= txtSearchValue.replace(/ +/g, "-");window.location="http://www.hindustantimes.com/search?q="+finalSearchKeywords;}}
#        </script>
#        <script type="text/javascript">
#         $(document).ready(function() {
# 				  $('#newsearchbox_new').keydown(function(e) {
# 					var txtSearchValue=document.getElementById("newsearchbox_new").value;
# 				    if (e.which === 13) {
# 				      if ($('#newsearchbox_new').val() != '') {
# 				    	  var finalSearchKeywords= txtSearchValue.replace(/ +/g, "-");
# 						  var url = "http://www.hindustantimes.com/search?q="+finalSearchKeywords;
# 						  window.location.href=url;
# 						  return false;
# 				      }
# 				    }
# 				  });
# 				});
#        </script>
#       </div>
#      </div>
#      <script>
#       if('opinionanalysis'.indexOf('fifa-u17-world-cup-2017')>=0) $('#amenu-sports-fifa-col').attr('class', 'active');else if('opinionanalysis'.indexOf('india-vs-australia-2017')>=0) $('#amenu-cricket-col').attr('class', 'active');else if('opinionanalysis'.indexOf('what-now')>=0) $('#amenu-what-now-col').attr('class', 'active'); else if('opinionanalysis'.indexOf('education')>=0) $('#amenu-education-col').attr('class', 'active'); else if('opinionanalysis'.indexOf('cricket')>=0) $('#amenu-sports-col').attr('class', 'active'); else if('opinionanalysis'.indexOf('photos')>=0) $('#amenu-photos-col').attr('class', 'active'); else if('opinionanalysis'.indexOf('videos')>=0) $('#amenu-videos-col').attr('class', 'active');	else if('opinionanalysis'.indexOf('entertainment')>=0) $('#amenu-entertainment-col').attr('class', 'active');	else if('opinionanalysis'.indexOf('lifestyle')>=0) $('#amenu-lifestyle-col').attr('class', 'active');	else if('opinionanalysis'.indexOf('india')>=0) $('#amenu-india-col').attr('class', 'active');	else if('opinionanalysis'.indexOf('world')>=0) $('#amenu-world-col').attr('class', 'active');	else if('opinionanalysis'.indexOf('cities')>=0)	$('#amenu-cities-col').attr('class', 'active');	else if('opinionanalysis'.indexOf('opinion')>=0)	$('#amenu-opinion-col').attr('class', 'active'); else if('opinionanalysis'.indexOf('sports')>=0)	$('#amenu-sports-col').attr('class', 'active');	else if('opinionanalysis'.indexOf('tech')>=0)	$('#amenu-tech-col').attr('class', 'active'); else if('opinionanalysis'.indexOf('more')>=0) $('#amenu-more-opt').attr('class', 'active'); else if('opinionanalysis'.indexOf('assembly-elections')>=0) $('#amenu-assembly-elections-col').attr('class', 'active'); else if('opinionanalysis'.indexOf('icc-champions-trophy')>=0) $('#amenu-cricket-col').attr('class', 'active');
#      </script>
#     </section>
#    </header>
#    <div class="container">
#     <div class="row">
#      <div class="col-md-12 col-lg-12 mt-10" style="z-index:99 !important;">
#       <div id="div-gpt-ad-1479816299356-2">
#        <script type="text/javascript">
#         googletag.cmd.push(function() {googletag.display('div-gpt-ad-1479816299356-2');});
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#    <section class="container">
#     <div class="story-section">
#      <div class="clearfix story-area">
#       <div class="story-area-left">
#        <article class="story-article">
#         <div class="story-highlight">
#          <h1 itemprop="headline">
#           Instant triple talaq: Supreme Court verdict is a landmark for gender justice
#          </h1>
#          <h2>
#           In the 31 years since the passing of the Muslim Women (Protection of Rights under Divorce) Act , the Supreme Court has consistently batted for the rights of minority women
#          </h2>
#          <a class="cta-link opinion-cb-section mr-15" href="http://www.hindustantimes.com/analysis/">
#           analysis
#          </a>
#          <span class="text-dt">
#           Updated: Aug 22, 2017 17:29 IST
#          </span>
#          <meta content="Aug 22, 2017 13:32+00:00" itemprop="datePublished"/>
#          <meta content="Aug 22, 2017 17:29+00:00" itemprop="dateModified"/>
#          <div class="media user-dt">
#           <div class="media-left">
#            <div class="media-img author-sm-img">
#             <img alt="Namita Bhandare" src="http://www.hindustantimes.com/rf/image_size_90x90/HT/Web/AuthorsAndColumnists/Pictures/Crop/Namita-Bhandare-0173-k5UC-U105377920JB-250x250%40HT-Web.JPG"/>
#            </div>
#           </div>
#           <div class="media-body">
#            <div class="para-txt" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#             <a href="http://www.hindustantimes.com/columns/namita-bhandare">
#              <span itemprop="name">
#               Namita Bhandare
#              </span>
#             </a>
#             <br/>
#            </div>
#           </div>
#          </div>
#          <div class="story-lg-img">
#           <div class="thumbnail" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#            <meta content="http://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2017/08/22/Pictures/farha-faiz_3ecef290-8731-11e7-a194-d8b7abb7611c.jpg" itemprop="url">
#             <img 22."="" alt="Farha Faiz, a Supreme Court lawyer, speaks to the media after the apex court declared " august="" in="" its="" src="http://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2017/08/22/Pictures/farha-faiz_3ecef290-8731-11e7-a194-d8b7abb7611c.jpg" talaq",="" title="Instant triple talaq" triple="" unconstitutional="" verdict,="">
#              <meta content="540" itemprop="height">
#               <meta content="960" itemprop="width">
#               </meta>
#              </meta>
#             </img>
#            </meta>
#           </div>
#           <div class="img-captionh2">
#            Farha Faiz, a Supreme Court lawyer, speaks to the media after the apex court declared "Triple Talaq", unconstitutional in its verdict, August  22. (AP)
#           </div>
#          </div>
#         </div>
#         <div class="story-content">
#          <script>
#           function sharePage(url,width, height) {
# 	 var leftPosition, topPosition;
# 	    //Allow for borders.
# 	 leftPosition = (window.screen.width / 2) - ((width / 2) + 10);
# 	    //Allow for title and status bars.
# 	topPosition = (window.screen.height / 2) - ((height / 2) + 50);
#     newwindow =  window.open(url, "name",
#     	    "status=no,height=" + height + ",width=" + width + ",resizable=yes,left="
#     	    + leftPosition + ",top=" + topPosition + ",screenX=" + leftPosition + ",screenY="
#     	    + topPosition + ",toolbar=no,menubar=no,scrollbars=no,location=no,directories=no");
#     if (window.focus) {
#         newwindow.focus()
#     }
#     return false;
# }
#          </script>
#          <input id="controller" name="controller" type="hidden" value="defaultValue"/>
#          <div class="social-icons-ar no-print">
#           <ul class="social-list-icon">
#            <li>
#             <a href="javascript:void(0)">
#              <i aria-hidden="true" class="fa fa-facebook story-fb" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html',400,350);" title="Facebook Share">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)">
#              <i aria-hidden="true" class="fa fa-twitter story-tw" onclick="sharePage('https://twitter.com/share?url=http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html&amp;text=Instant triple talaq: Supreme Court verdict is a landmark for gender justice via @htTweets',500,600);" title="Tweet">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)">
#              <i aria-hidden="true" class="fa fa-linkedin story-lnkden" onclick="sharePage('https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html&amp;title=&amp;summary=&amp;source=',600,600);" title="Linkdin Share">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)">
#              <i aria-hidden="true" class="fa fa-google-plus story-gplus" onclick="sharePage('https://plus.google.com/share?url=http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html',500,450);" title="Google Plus Share">
#              </i>
#             </a>
#            </li>
#            <!-- <li><a href="javascript:void(0)">
# 							<i class="icons comment-col-icons">143</i></a></li> -->
#            <li>
#             <a href="http://www.reddit.com/submit?url=http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html&amp;title=Instant triple talaq: Supreme Court verdict is a landmark for gender justice" target="_blank">
#              <i aria-hidden="true" class="fa fa-reddit-alien story-reddit" onclick="window.location ='http://www.reddit.com/submit?url=http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html&amp;title=Instant triple talaq: Supreme Court verdict is a landmark for gender justice'  return false">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="mailto:please enter email id?Subject=Hindustantimes.com | Instant triple talaq: Supreme Court verdict is a landmark for gender justice&amp;Body=Instant triple talaq: Supreme Court verdict is a landmark for gender justice-http://www.hindustantimes.com/analysis/instant-triple-talaq-supreme-court-verdict-is-a-landmark-for-gender-justice/story-NkHU3oDV1R5wastZWliqBI.html">
#              <i aria-hidden="true" class="fa fa-envelope story-email">
#              </i>
#             </a>
#            </li>
#            <li>
#             <a href="javascript:window.print()">
#              <i aria-hidden="true" class="fa fa-print story-prnt">
#              </i>
#             </a>
#            </li>
#            <!-- 	<li class="footprit-step"><a href="javascript:void(0)"
# 								class="footprit"> <img src="images/foot-print1.png"
# 									alt="foot Print" />
# 							</a>
# 								<div class="follow-st">
# 									<div class="arrow-left"></div>
# 									Follow Story
# 								</div>
# 								<div class="foot-jump">
# 									<div class="foot-jump-foot">
# 										<div class="ajax-loader1">
# 											<div class="paw">
# 												<svg class="icon">
# 													<use xlink:href="#paw" /></svg>
# 											</div>
# 											<div class="paw">
# 												<svg class="icon">
# 													<use xlink:href="#paw" /></svg>
# 											</div>
# 											<div class="paw">
# 												<svg class="icon">
# 													<use xlink:href="#paw" /></svg>
# 											</div>
# 											<div class="paw">
# 												<svg class="icon">
# 													<use xlink:href="#paw" /></svg>
# 											</div>
# 											<div class="paw">
# 												<svg class="icon">
# 													<use xlink:href="#paw" /></svg>
# 											</div>
# 											<div class="paw">
# 												<svg class="icon">
# 													<use xlink:href="#paw" /></svg>
# 											</div>
# 										</div>
# 									</div>
# 									<div class="follow-st">
# 										<div class="arrow-left"></div>
# 										Follow Story
# 									</div>
# 								</div></li> -->
#           </ul>
#          </div>
#          <div class="story-details" itemprop="articlebody">
#           <p>
#            A majority ruling of the Supreme Court has declared instant triple talaq unconstitutional and unIslamic. It has asked Parliament to ‘put aside politics’ and frame an appropriate law. Starting now, the practice is invalid and it is up to Parliament to frame an appropriate law that will make it illegal as well. This is a ruling that is both in sync with Constitutional propriety – law-making is Parliament’s prerogative – and the principles of natural justice.
#           </p>
#           <p>
#            Parliament has not exactly crowned itself with glory when it comes to gender justice for minority women, starting from the ironically-named Muslim Women (Protection of Rights under Divorce) Act passed by the Rajiv Gandhi government in 1986. The Act was brought in  to overturn and subvert an earlier Supreme Court ruling to grant maintenance to Shah Bano, a 62-year-old Muslim mother of five who had been divorced by her husband. What Parliament essentially did was to limit divorced Muslim women to maintenance only for the iddat period (roughly three months) after which they would have to depend on the charity of relatives or Waqf boards.
#           </p>
#           <p>
#            Yet in the 31 years since the passing of that act, the Supreme Court has, to its credit, consistently batted for the rights of minority women. When Danial Latifi, incidentally, Shah Bano’s lawyer, appealed against a High Court ruling ordering him to pay Rs 179 a month to his divorced wife for 43 years, the Supreme Court ruled that the Muslim Women Act had to be read in conjunction with the Constitution that guarantees dignity and equality to women.
#           </p>
#           <p>
#            When a two-judge bench in 2015 observed that polygamy was not ‘an integral part of religion’ or gave Muslim women the right to adopt or asked the government to make amendments to an arbitrary rule under which Christian couples seeking a divorce had to be separated for two years, instead of the one by couples from other religions, it was in effect coming to the aid of the rights of women.
#           </p>
#           <p>
#            Yet, 70 years after Independence, gender justice cannot be an abstract idea to which we have a piecemeal approach. The Supreme Court’s own recent rulings on, say 498A, a section that is undoubtedly misused but nevertheless a section that is needed to protect victims of the ongoing dowry malaise, leave a lot to be desired. There was criticism too of a recent ruling on ‘love jihad’ or the decision to marry a man outside her religion by an adult woman.
#           </p>
#           <span class="read-more">
#           </span>
#           <p>
#            Certainly, we must ask why the Supreme Court took up triple talaq with such a sense of urgency during vacation time but chose to ignore a demand for a ban on other heinous practices like nikaah halala (a process by which a Muslim woman must consummate an intervening marriage before she remarries a divorced husband) and polygamy by the petitioners.
#           </p>
#           <p>
#            And certainly, we must be concerned by the lack of gender diversity within the august benches of our Supreme Court. While much is made of the representation of women in Parliament where they comprise an all-time high of a pathetic 11.3% per cent, relatively little noise is made about the fact that of the 229 judges appointed to the Supreme Court since 1950, only six have been women and at present only one of all Supreme Court judges at present is a woman.
#           </p>
#           <p>
#            Gender justice that includes diversity and representation cannot be a neat little slogan. It must be performed and demonstrated every day and everywhere. Nobody wants to rain on a grand moment for gender rights, which is what the present Supreme Court judgment undoubtedly is. But equally, this is as good a time as any to push and ask for a society where afflicted women don’t have to approach the courts to demand their most basic human rights and where courts don’t have to remind Parliament of its function in protecting the rights of 48.5% of our country’s citizens.
#           </p>
#           <span class="read-more">
#           </span>
#           <p>
#            If there is a hero to be found in this historic moment it is the collective women petitioners who took it upon themselves to knock on the doors of the Supreme Court and demand that it listen to their plight. My friends at the Bharatiya Mahila Muslim Andolan have braved ostracism and abuse in their long journey to judgment day.
#           </p>
#           <p>
#            India is a changed country since the over three decades of the Shah Bano judgment. If any proof was needed of that, it is in today’s judgment in response to a new generation of women who will not suffer in silence any longer. But while it’s not out of place to take a moment to celebrate a hard-won victory, let’s not delude ourselves that the battle has been won.
#           </p>
#           <p>
#            <b>
#             <i>
#              Namita Bhandare writes on social issues and gender.
#             </i>
#            </b>
#           </p>
#           <p>
#            <b>
#             <i>
#              The views expressed are personal
#             </i>
#            </b>
#            .
#           </p>
#          </div>
#          <div class="no-print clearfix">
#          </div>
#         </div>
#        </article>
#        <div class="more-politics-area no-print">
#         <!-- Story Heading -->
#         <div class="column-head">
#          <div class="new-h2-head">
#           <a class="more-link">
#            more from analysis
#           </a>
#          </div>
#         </div>
#         <ul class="latest-news-bx row">
#          <li class="col-sm-12 col-md-6">
#           <div class="media">
#            <div class="media-left">
#             <div class="media-img">
#              <a href="http://www.hindustantimes.com/analysis/delhi-s-queer-pride-parade-a-short-gasp-of-breath-in-a-choked-environment/story-7tXgOrFqonobRHXOoWi8iP.html" onclick="dataLayer.push({'event':'story_page_container', 'action': 'more_from_container_click', 'label': 'http://www.hindustantimes.com/analysis/delhi-s-queer-pride-parade-a-short-gasp-of-breath-in-a-choked-environment/story-7tXgOrFqonobRHXOoWi8iP.html' })">
#               <img class="lazy" data-src="http://www.hindustantimes.com/rf/image_size_90x90/HT/p2/2017/11/13/Pictures/queer-pride-march_787fac44-c84c-11e7-8cd0-7e09bc26593d.jpg" src="http://www.hindustantimes.com/res/img/app-images/HomePageV1/zero.gif"/>
#              </a>
#             </div>
#            </div>
#            <div class="media-body">
#             <div class="media-heading headingfour">
#              <a href="http://www.hindustantimes.com/analysis/delhi-s-queer-pride-parade-a-short-gasp-of-breath-in-a-choked-environment/story-7tXgOrFqonobRHXOoWi8iP.html" onclick="dataLayer.push({'event':'story_page_container', 'action': 'more_from_container_click', 'label': 'http://www.hindustantimes.com/analysis/delhi-s-queer-pride-parade-a-short-gasp-of-breath-in-a-choked-environment/story-7tXgOrFqonobRHXOoWi8iP.html' })">
#               Delhi’s queer pride parade: A short gasp of breath in a choked environment
#              </a>
#             </div>
#             <span class="time-dt">
#              Nov 13, 2017 17:42 IST
#             </span>
#            </div>
#           </div>
#          </li>
#          <li class="col-sm-12 col-md-6">
#           <div class="media">
#            <div class="media-left">
#             <div class="media-img">
#              <a href="http://www.hindustantimes.com/analysis/the-greatest-threat-to-psu-banks-are-fintech-disruptions/story-muAjsRes3faiMrycz0wobP.html" onclick="dataLayer.push({'event':'story_page_container', 'action': 'more_from_container_click', 'label': 'http://www.hindustantimes.com/analysis/the-greatest-threat-to-psu-banks-are-fintech-disruptions/story-muAjsRes3faiMrycz0wobP.html' })">
#               <img class="lazy" data-src="http://www.hindustantimes.com/rf/image_size_90x90/HT/p2/2017/11/11/Pictures/pnb_f4d7b696-c6ea-11e7-a37e-1053cac6ca52.jpg" src="http://www.hindustantimes.com/res/img/app-images/HomePageV1/zero.gif"/>
#              </a>
#             </div>
#            </div>
#            <div class="media-body">
#             <div class="media-heading headingfour">
#              <a href="http://www.hindustantimes.com/analysis/the-greatest-threat-to-psu-banks-are-fintech-disruptions/story-muAjsRes3faiMrycz0wobP.html" onclick="dataLayer.push({'event':'story_page_container', 'action': 'more_from_container_click', 'label': 'http://www.hindustantimes.com/analysis/the-greatest-threat-to-psu-banks-are-fintech-disruptions/story-muAjsRes3faiMrycz0wobP.html' })">
#               The greatest threat to PSU banks are fintech disruptions
#              </a>
#             </div>
#             <span class="time-dt">
#              Nov 12, 2017 16:19 IST
#             </span>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </div>
#        <div id="taboola-below-article-thumbnails">
#        </div>
#        <script type="text/javascript">
#         window._taboola = window._taboola || [];
# 				  _taboola.push({
# 				    mode: 'thumbnails-a',
# 				    container: 'taboola-below-article-thumbnails',
# 				    placement: 'Below Article Thumbnails',
# 				    target_type: 'mix'
# 				  });
#        </script>
#        <!-- <div id="rcjsload_d76286"></div>
# <script type="text/javascript">
# 	(function() {
# 		var referer = "";
# 		try {
# 			if (referer = document.referrer, "undefined" == typeof referer)
# 				throw "undefined"
# 		} catch (exception) {
# 			referer = document.location.href,
# 					("" == referer || "undefined" == typeof referer)
# 							&& (referer = document.URL)
# 		}
# 		referer = referer.substr(0, 700);
# 		var rcel = document.createElement("script");
# 		rcel.id = 'rc_' + Math.floor(Math.random() * 1000);
# 		rcel.type = 'text/javascript';
# 		rcel.src = "http://trends.revcontent.com/serve.js.php?w=50924&t="
# 				+ rcel.id + "&c=" + (new Date()).getTime() + "&width="
# 				+ (window.outerWidth || document.documentElement.clientWidth)
# ...
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/business-news/not-to-pursue-islamic-banking-in-india-says-rbi/story-QvO9RunFLPCc5kT6DROrKI.html">
#        Will not pursue Islamic banking in India, says RBI
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 12, 2017 11:46 IST
#      </span>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
# <div id="menu_tech9" style="display:none">
#  <div class="sub-menu-dt">
#   <div class="clearfix">
#    <div class="col-md-3">
#     <div class="gallery-cont">
#      <a href="http://www.hindustantimes.com/tech/oppo-reliance-jio-team-up-to-offer-up-to-100gb-free-data-with-select-models/story-pmgGT1et4HlFAQHj5msJOK.html">
#       <img alt="OPPO, Reliance Jio team up to offer up to 100GB free data with select..." src="http://www.hindustantimes.com/rf/image_size_300x200/HT/p2/2017/11/13/Pictures/_e7bf747c-c86f-11e7-8cd0-7e09bc26593d.jpg"/>
#      </a>
#      <a href="http://www.hindustantimes.com/tech/oppo-reliance-jio-team-up-to-offer-up-to-100gb-free-data-with-select-models/story-pmgGT1et4HlFAQHj5msJOK.html">
#       <div class="para-txt">
#        OPPO, Reliance Jio team up to offer up to 100GB free data with select models
#       </div>
#      </a>
#     </div>
#     <span class="time-dt">
#      Nov 13, 2017 18:13 IST
#     </span>
#    </div>
#   </div>
#   <div class="col-md-9">
#    <ul class="row headlines-cont">
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/tech/moto-x4-first-impressions-a-shiny-new-smartphone-in-the-mid-range-category/story-9YKR7fFfROS1ZBfs1X2YIJ.html">
#        Moto X4 first impressions: A shiny new smartphone in the mid-range category
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 16:27 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/tech/moto-x4-with-snapdragon-630-soc-launched-in-india-price-starts-at-rs-20-999/story-TXMttenCIDGx8ZQAcxOCzJ.html">
#        Moto X4 with Snapdragon 630 SoC launched in India, price starts at Rs 20,999
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 15:18 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/tech/facebook-rebrands-events-app-as-facebook-local-takes-on-yelp-and-foursquare/story-XlsMEP8F7vHDXkSu4cHliJ.html">
#        Facebook rebrands ‘Events’ app as ‘Facebook Local’, takes on Yelp and Foursquare
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 14:32 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/tech/is-face-id-secure-researchers-hack-facial-recognition-tech-using-3d-printed-mask/story-pMvyGZfiuxlJUpiy2bkYPK.html">
#        Is Face ID secure? Researchers hack facial recognition tech using 3D-printed ma...
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 11:31 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/tech/google-warns-developers-against-misusing-accessibility-services/story-3pykVxHR77g2Ur22pEqaaI.html">
#        Google warns developers against misusing Accessibility services
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 11:13 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/tech/samsung-unveils-exynos-9-series-9810-soc-set-to-power-galaxy-s9/story-r7mYXShL3SX74Z2GfYQyeM.html">
#        Samsung unveils Exynos 9 Series 9810 SoC, set to power Galaxy S9
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 10:13 IST
#      </span>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
# <div id="menu_education10" style="display:none">
#  <div class="sub-menu-dt">
#   <div class="clearfix">
#    <div class="col-md-3">
#     <div class="gallery-cont">
#      <a href="http://www.hindustantimes.com/education/indian-students-in-us-doubled-in-last-decade/story-xS4sdXHs6eRr7v4tZtPguN.html">
#       <img alt="Indian students in US double in last decade, second only to the..." src="http://www.hindustantimes.com/rf/image_size_300x200/HT/p2/2017/11/13/Pictures/scholarships_80668476-c871-11e7-855e-d08d9ee048bd.jpg"/>
#      </a>
#      <a href="http://www.hindustantimes.com/education/indian-students-in-us-doubled-in-last-decade/story-xS4sdXHs6eRr7v4tZtPguN.html">
#       <div class="para-txt">
#        Indian students in US double in last decade, second only to the Chinese
#       </div>
#      </a>
#     </div>
#     <span class="time-dt">
#      Nov 13, 2017 18:37 IST
#     </span>
#    </div>
#   </div>
#   <div class="col-md-9">
#    <ul class="row headlines-cont">
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/education/army-takes-j-k-students-on-tour-for-capacity-building/story-vxqRzVMI4ermXkxuvA4XNJ.html">
#        Army takes J-K students on tour for capacity building
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 15:34 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/education/ibps-po-main-admit-card-call-letter-2017-released-download-it-now/story-D1BoYrqLD1ejHIcHlSKHhP.html">
#        IBPS PO main admit card/call letter 2017 released, download it now
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 15:21 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/education/children-and-mental-health-illness-11-things-to-keep-in-mind/story-xkvTd7DR3655cM5rjT82uK.html">
#        Children and mental illness: 11 things to keep in mind
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 13:24 IST
#      </span>
#     </li>
#     <li class="col-sm-6">
#      <div class="headingfour">
#       <a href="http://www.hindustantimes.com/education/cbse-students-get-more-time-to-correct-errors-in-mark-sheets/story-3H3V8pAcqgm9h6VLEnIQVJ.html">
#        CBSE students get more time to correct errors in mark sheets
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 09:35 IST
#      </span>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
# <div id="menu_what-now11" style="display:none">
#  <div class="sub-menu-dt">
#   <div class="clearfix">
#    <div class="col-md-3">
#     <div class="gallery-cont">
#     </div>
#    </div>
#    <div class="col-md-9">
#     <ul class="row headlines-cont">
#     </ul>
#    </div>
#   </div>
#  </div>
# </div>
# <div id="menu_photos12" style="display:none">
#  <div class="sub-menu-dt">
#   <div class="clearfix">
#    <div class="col-md-3">
#     <div class="gallery-cont">
#      <a href="http://www.hindustantimes.com/photos/india-news/photos-darjeeling-tea-industry-crisis-low-production-political-unrest/photo-29jy90gZJlvNUJ6mZbV5RO.html">
#       <img alt="Photos: Darjeeling tea industry crisis; low production,..." src="http://www.hindustantimes.com/rf/image_size_300x200/HT/p2/2017/11/13/Pictures/indranil-october-darjeeling-darjeeling-october-workers-plucking_4fb14736-c85c-11e7-869c-1f24c33974c8.JPG"/>
#      </a>
#      <div class="para-txt">
#       <a href="http://www.hindustantimes.com/photos/india-news/photos-darjeeling-tea-industry-crisis-low-production-political-unrest/photo-29jy90gZJlvNUJ6mZbV5RO.html">
#        Photos: Darjeeling tea industry crisis; low production, political unrest
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 16:42 IST
#      </span>
#     </div>
#    </div>
#    <div class="col-md-9">
#     <ul class="row headlines-cont">
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <span>
#         <a href="http://www.hindustantimes.com/photos/cities/a-walk-down-the-memory-lane-what-pune-s-most-iconic-places-looked-like-in-1960s/photo-bTh2jtd9oLpHewKgBst9aK.html">
#          200 years of Pune Cantonment: What Pune’s most iconic places...
#         </a>
#        </span>
#       </div>
#       <span class="time-dt">
#        Nov 13, 2017 18:30 IST
#       </span>
#      </li>
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <span>
#         <a href="http://www.hindustantimes.com/photos/world-news/photos-7-3-magnitude-earthquake-on-iran-iraq-border-kills-160/photo-37rIvLXVw24l8ZffvPw6dJ.html">
#          Photos: 7.3 magnitude earthquake on Iran-Iraq border kills over 300
#         </a>
#        </span>
#       </div>
#       <span class="time-dt">
#        Nov 13, 2017 14:40 IST
#       </span>
#      </li>
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <span>
#         <a href="http://www.hindustantimes.com/photos/india-news/photos-10th-queer-pride-brings-delhi-to-the-streets-in-celebration/photo-sCWLCWpDDuBkNeVR93R80O.html">
#          Photos: 10th Queer pride brings Delhi to the streets in celebration
#         </a>
#        </span>
#       </div>
#       <span class="time-dt">
#        Nov 13, 2017 11:09 IST
#       </span>
#      </li>
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <span>
#         <a href="http://www.hindustantimes.com/photos/other-sports/virat-kohli-sania-mirza-top-stars-dazzle-at-indian-sports-honours/photo-HRXblbR45FNXgD9qE0dRmK.html">
#          Virat Kohli, Sania Mirza &amp; top stars dazzle at Indian Sports...
#         </a>
#        </span>
#       </div>
#       <span class="time-dt">
#        Nov 12, 2017 10:15 IST
#       </span>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </div>
# </div>
# <div id="menu_videos13" style="display:none">
#  <div class="sub-menu-dt">
#   <div class="clearfix">
#    <div class="col-md-3">
#     <div class="gallery-cont">
#      <a href="http://www.hindustantimes.com/videos/football/marcus-rashford-reveals-admiration-for-ronaldo-ahead-of-england-brazil-friendly/video-LB5um15cw6FTtNfpajNa3I.html">
#       <img alt="England’s 20-year-old forward Marcus Rashford has revealed Brazilian..." src="http://www.hindustantimes.com/rf/image_size_300x200/HT/p2/2017/11/13/Pictures/fbl-wc-2018-eng-training_6bdb6d98-c874-11e7-855e-d08d9ee048bd.jpg"/>
#      </a>
#      <div class="para-txt">
#       <a href="http://www.hindustantimes.com/videos/football/marcus-rashford-reveals-admiration-for-ronaldo-ahead-of-england-brazil-friendly/video-LB5um15cw6FTtNfpajNa3I.html">
#        Marcus Rashford reveals admiration for Ronaldo ahead of England-Brazil friendly
#       </a>
#      </div>
#      <span class="time-dt">
#       Nov 13, 2017 18:45 IST
#      </span>
#     </div>
#    </div>
#    <div class="col-md-9">
#     <ul class="row headlines-cont">
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <a href="http://www.hindustantimes.com/videos/football/no-rift-between-neymar-and-edinson-cavani-says-psg-teammate-julian-draxler/video-jjC331uXOQgnN43yK05kHI.html">
#         No rift between Neymar and Edinson Cavani, says PSG teammate Julian Draxler
#        </a>
#       </div>
#       <span class="time-dt">
#        Nov 13, 2017 18:45 IST
#       </span>
#      </li>
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <a href="http://www.hindustantimes.com/videos/football/gianluigi-buffon-urges-fans-to-get-behind-italy-ahead-of-sweden-clash/video-V8uFPDoEybK1XPEyACb32K.html">
#         Gianluigi Buffon urges fans to get behind Italy ahead of Sweden clash
#        </a>
#       </div>
#       <span class="time-dt">
#        Nov 13, 2017 12:35 IST
#       </span>
#      </li>
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <a href="http://www.hindustantimes.com/videos/football/switzerland-manager-satisfied-after-qualifying-for-fifa-world-cup-2018/video-lsA2AFh2Vo41K00qXmYC8L.html">
#         Switzerland manager ‘satisfied’ after qualifying for FIFA World Cup 2018
#        </a>
#       </div>
#       <span class="time-dt">
#        Nov 13, 2017 12:03 IST
#       </span>
#      </li>
#      <li class="col-sm-6">
#       <div class="headingfour">
#        <a href="http://www.hindustantimes.com/videos/football/martin-o-neill-wants-more-creativity-from-ireland-after-0-0-1st-leg-vs-denmark/video-TnL7OJVQzfc6wxjLQ9tdPK.html">
#         Martin O’Neill wants more creativity from Ireland after 0-0 1st leg vs Denmark
#        </a>
#       </div>
#       <span class="time-dt">
#        Nov 12, 2017 17:01 IST
#       </span>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </div>
# </div>
# <div id="menu_more14" style="display:none">
#  <div class="sub-menu-dt sub-menu-open">
#   <ul class="sub-menu-list">
#    <li>
#     <a href="/interactives/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'interactives'})">
#      interactives
#     </a>
#    </li>
#    <li>
#     <a href="/longreads/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'longreads'})">
#      longreads
#     </a>
#    </li>
#    <li>
#     <a href="/health/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'health'})">
#      health
#     </a>
#    </li>
#    <li>
#     <a href="/real-estate/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'real-estate'})">
#      real-estate
#     </a>
#    </li>
#    <li>
#     <a href="/autos/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'autos'})">
#      autos
#     </a>
#    </li>
#    <li>
#     <a href="/punjab/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'punjab'})">
#      punjab
#     </a>
#    </li>
#    <li>
#     <a href="http://paper.hindustantimes.com/epaper/viewer.aspx" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'epaper'})" target="_blank">
#      epaper
#     </a>
#    </li>
#    <li>
#     <a href="/ht-brand-stories" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'ht-brand stories'})">
#      ht-brand stories
#     </a>
#    </li>
#    <li>
#     <a href="/weekend/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'weekend'})">
#      weekend
#     </a>
#    </li>
#    <li>
#     <a href="/science/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'science'})" target="_blank">
#      science
#     </a>
#    </li>
#    <li>
#     <a href="/environment/" onclick="dataLayer.push({'event':'navigtion_menu', 'action': 'L2', 'label': 'environment'})" target="_blank">
#      environment
#     </a>
#    </li>
#   </ul>
#  </div>
# </div>
# <script src="http://www.hindustantimes.com/res/js-ns/script.js?v=1" type="text/javascript">
# </script>
# <script src="http://www.hindustantimes.com/res/js-ns/ie10-viewport-bug-workaround.js" type="text/javascript">
# </script>
# <script src="http://www.hindustantimes.com/res/js-ns/core-api-v1.js?v=45" type="text/javascript">
# </script>
# <div id="z391c87c8-aa82-45a7-a78f-84c7fd512e89" style="display:none">
# </div>
# <script>
#  !function(a,n,e,t,r){tagsync=e;var c=window[a];if(tagsync){var d=document.createElement("script");d.src="https://294.tm.zedo.com/v1/dac2a6fe-36f6-4a52-87d8-661f5e135748/atm.js",d.async=!0;var i=document.getElementById(n);if(null==i||"undefined"==i)return;i.parentNode.appendChild(d,i),d.onload=d.onreadystatechange=function(){var a=new zTagManager(n);a.initTagManager(n,c,this.aync,t,r)}}else document.write("<script src='https://294.tm.zedo.com/v1/dac2a6fe-36f6-4a52-87d8-661f5e135748/tm.js?data="+a+"'><"+"/script>")}("datalayer","z391c87c8-aa82-45a7-a78f-84c7fd512e89",true, 1 , 1);
# </script>
# <script type="text/javascript">
#  var _sf_async_config = _sf_async_config || {};   _sf_async_config.uid = 63228; _sf_async_config.domain = "hindustantimes.com"; _sf_async_config.useCanonical = true; _sf_async_config.sections ="opinion/analysis"; _sf_async_config.authors = "Namita Bhandare";	(function(){function loadChartbeat() {window._sf_endpt=(new Date()).getTime();var e = document.createElement('script'); e.setAttribute('language', 'javascript'); e.setAttribute('type', 'text/javascript'); e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js'); document.body.appendChild(e); }var oldonload = window.onload; window.onload = (typeof window.onload != 'function') ? loadChartbeat : function() { oldonload(); loadChartbeat(); }; })();
# </script>

# %%
all_links = soup.find_all("p")
data = []
for link in all_links:
    data.append(link.text)
print(data)
# Out:
# ['A majority ruling of the Supreme Court has declared instant triple talaq unconstitutional and unIslamic. It has asked Parliament to ‘put aside politics’ and frame an appropriate law. Starting now, the practice is invalid and it is up to Parliament to frame an appropriate law that will make it illegal as well. This is a ruling that is both in sync with Constitutional propriety – law-making is Parliament’s prerogative – and the principles of natural justice. ', 'Parliament has not exactly crowned itself with glory when it comes to gender justice for minority women, starting from the ironically-named Muslim Women (Protection of Rights under Divorce) Act passed by the Rajiv Gandhi government in 1986. The Act was brought in  to overturn and subvert an earlier Supreme Court ruling to grant maintenance to Shah Bano, a 62-year-old Muslim mother of five who had been divorced by her husband. What Parliament essentially did was to limit divorced Muslim women to maintenance only for the iddat period (roughly three months) after which they would have to depend on the charity of relatives or Waqf boards. ', 'Yet in the 31 years since the passing of that act, the Supreme Court has, to its credit, consistently batted for the rights of minority women. When Danial Latifi, incidentally, Shah Bano’s lawyer, appealed against a High Court ruling ordering him to pay Rs 179 a month to his divorced wife for 43 years, the Supreme Court ruled that the Muslim Women Act had to be read in conjunction with the Constitution that guarantees dignity and equality to women. ', 'When a two-judge bench in 2015 observed that polygamy was not ‘an integral part of religion’ or gave Muslim women the right to adopt or asked the government to make amendments to an arbitrary rule under which Christian couples seeking a divorce had to be separated for two years, instead of the one by couples from other religions, it was in effect coming to the aid of the rights of women. ', 'Yet, 70 years after Independence, gender justice cannot be an abstract idea to which we have a piecemeal approach. The Supreme Court’s own recent rulings on, say 498A, a section that is undoubtedly misused but nevertheless a section that is needed to protect victims of the ongoing dowry malaise, leave a lot to be desired. There was criticism too of a recent ruling on ‘love jihad’ or the decision to marry a man outside her religion by an adult woman. ', 'Certainly, we must ask why the Supreme Court took up triple talaq with such a sense of urgency during vacation time but chose to ignore a demand for a ban on other heinous practices like nikaah halala (a process by which a Muslim woman must consummate an intervening marriage before she remarries a divorced husband) and polygamy by the petitioners. ', 'And certainly, we must be concerned by the lack of gender diversity within the august benches of our Supreme Court. While much is made of the representation of women in Parliament where they comprise an all-time high of a pathetic 11.3% per cent, relatively little noise is made about the fact that of the 229 judges appointed to the Supreme Court since 1950, only six have been women and at present only one of all Supreme Court judges at present is a woman. ', 'Gender justice that includes diversity and representation cannot be a neat little slogan. It must be performed and demonstrated every day and everywhere. Nobody wants to rain on a grand moment for gender rights, which is what the present Supreme Court judgment undoubtedly is. But equally, this is as good a time as any to push and ask for a society where afflicted women don’t have to approach the courts to demand their most basic human rights and where courts don’t have to remind Parliament of its function in protecting the rights of 48.5% of our country’s citizens. ', 'If there is a hero to be found in this historic moment it is the collective women petitioners who took it upon themselves to knock on the doors of the Supreme Court and demand that i ...

# %%
data= str(data)
data = data.lower()
all_documents = sent_tokenize(data)
print(all_documents)
print(len(all_documents))
# Out:
# ["['a majority ruling of the supreme court has declared instant triple talaq unconstitutional and unislamic.", 'it has asked parliament to ‘put aside politics’ and frame an appropriate law.', 'starting now, the practice is invalid and it is up to parliament to frame an appropriate law that will make it illegal as well.', 'this is a ruling that is both in sync with constitutional propriety – law-making is parliament’s prerogative – and the principles of natural justice.', "', 'parliament has not exactly crowned itself with glory when it comes to gender justice for minority women, starting from the ironically-named muslim women (protection of rights under divorce) act passed by the rajiv gandhi government in 1986. the act was brought in  to overturn and subvert an earlier supreme court ruling to grant maintenance to shah bano, a 62-year-old muslim mother of five who had been divorced by her husband.", 'what parliament essentially did was to limit divorced muslim women to maintenance only for the iddat period (roughly three months) after which they would have to depend on the charity of relatives or waqf boards.', "', 'yet in the 31 years since the passing of that act, the supreme court has, to its credit, consistently batted for the rights of minority women.", 'when danial latifi, incidentally, shah bano’s lawyer, appealed against a high court ruling ordering him to pay rs 179 a month to his divorced wife for 43 years, the supreme court ruled that the muslim women act had to be read in conjunction with the constitution that guarantees dignity and equality to women.', "', 'when a two-judge bench in 2015 observed that polygamy was not ‘an integral part of religion’ or gave muslim women the right to adopt or asked the government to make amendments to an arbitrary rule under which christian couples seeking a divorce had to be separated for two years, instead of the one by couples from other religions, it was in effect coming to the aid of the rights of women.", "', 'yet, 70 years after independence, gender justice cannot be an abstract idea to which we have a piecemeal approach.", 'the supreme court’s own recent rulings on, say 498a, a section that is undoubtedly misused but nevertheless a section that is needed to protect victims of the ongoing dowry malaise, leave a lot to be desired.', 'there was criticism too of a recent ruling on ‘love jihad’ or the decision to marry a man outside her religion by an adult woman.', "', 'certainly, we must ask why the supreme court took up triple talaq with such a sense of urgency during vacation time but chose to ignore a demand for a ban on other heinous practices like nikaah halala (a process by which a muslim woman must consummate an intervening marriage before she remarries a divorced husband) and polygamy by the petitioners.", "', 'and certainly, we must be concerned by the lack of gender diversity within the august benches of our supreme court.", 'while much is made of the representation of women in parliament where they comprise an all-time high of a pathetic 11.3% per cent, relatively little noise is made about the fact that of the 229 judges appointed to the supreme court since 1950, only six have been women and at present only one of all supreme court judges at present is a woman.', "', 'gender justice that includes diversity and representation cannot be a neat little slogan.", 'it must be performed and demonstrated every day and everywhere.', 'nobody wants to rain on a grand moment for gender rights, which is what the present supreme court judgment undoubtedly is.', 'but equally, this is as good a time as any to push and ask for a society where afflicted women don’t have to approach the courts to demand their most basic human rights and where courts don’t have to remind parliament of its function in protecting the rights of 48.5% of our country’s citizens.', "', 'if there is a hero to be found in this historic moment it is the collective women petitioners who took it upon themselves t ...
# 26

# %%
from __future__ import division
import string
import math
tokenize = lambda doc: doc.lower().split(" ")
for i in range(len(all_documents)):
    tokenized_documents = [tokenize(d) for d in all_documents] # tokenized docs
    all_tokens_set = set([item for sublist in tokenized_documents for item in sublist])

def sublinear_term_frequency(term, tokenized_document):
    count = tokenized_document.count(term)
    if count == 0:
        return 0
    return 1 + math.log(count)

def term_frequency(term, tokenized_document):
    return tokenized_document.count(term)

def inverse_document_frequencies(tokenized_documents):
    idf_values = {}
    all_tokens_set = set([item for sublist in tokenized_documents for item in sublist])
    for tkn in all_tokens_set:
        contains_token = map(lambda doc: tkn in doc, tokenized_documents)
        idf_values[tkn] = 1 + math.log(len(tokenized_documents)/(sum(contains_token)))
    return idf_values

def tfidf(documents):
    tokenized_documents = [tokenize(d) for d in documents]
    idf = inverse_document_frequencies(tokenized_documents)
    tfidf_documents = []
    for document in tokenized_documents:
        doc_tfidf = []
        for term in idf.keys():
            tf = sublinear_term_frequency(term, document)
            doc_tfidf.append((term,tf * idf[term]))
        tfidf_documents.append(doc_tfidf)
    return tfidf_documents

# %%
tfidf_representation = tfidf(all_documents)
print (tfidf_representation)
# Out:
# [[('', 0.0), ('or', 0.0), ('principles', 0.0), ('danial', 0.0), ('journey', 0.0), ('constitutional', 0.0), ('demand', 0.0), ('human', 0.0), ('iddat', 0.0), ('five', 0.0), ('(protection', 0.0), ('celebrate', 0.0), ('43', 0.0), ('man', 0.0), ('on', 0.0), ('expressed', 0.0), ('would', 0.0), ('2015', 0.0), ('desired.', 0.0), ('misused', 0.0), ('dowry', 0.0), ('48.5%', 0.0), ('longer.', 0.0), ('ongoing', 0.0), ("'and", 0.0), ('it’s', 0.0), ('independence,', 0.0), ('must', 0.0), ('afflicted', 0.0), ('bano’s', 0.0), ("'yet,", 0.0), ('an', 0.0), ('intervening', 0.0), ('seeking', 0.0), ('woman', 0.0), ("'india", 0.0), ('all-time', 0.0), ('rs', 0.0), ('one', 0.0), ('collective', 0.0), ('undoubtedly', 0.0), ('the', 1.3136575588550417), ('abuse', 0.0), ('nikaah', 0.0), ('‘put', 0.0), ('part', 0.0), ('has,', 0.0), ('wife', 0.0), ('dignity', 0.0), ('court', 2.1786549963416464), ('this', 0.0), ('to', 0.0), ('ignore', 0.0), ('within', 0.0), ('our', 0.0), ('changed', 0.0), ('talaq', 3.5649493574615367), ('protect', 0.0), ('ban', 0.0), ('instant', 4.258096538021482), ('we', 0.0), ('crowned', 0.0), ('ask', 0.0), ('idea', 0.0), ('for', 0.0), ('starting', 0.0), ('are', 0.0), ('years,', 0.0), ('be', 0.0), ('judgment.', 0.0), ('decision', 0.0), ('delude', 0.0), ('instead', 0.0), ('before', 0.0), ('vacation', 0.0), ('chose', 0.0), ('victory,', 0.0), ('outside', 0.0), ('pay', 0.0), ('per', 0.0), ('period', 0.0), ('doors', 0.0), ('couples', 0.0), ('marriage', 0.0), ('religion’', 0.0), ('divorced', 0.0), ('new', 0.0), ('politics’', 0.0), ('my', 0.0), ('where', 0.0), ('place', 0.0), ('neat', 0.0), ('prerogative', 0.0), ('separated', 0.0), ('judgment', 0.0), ('divorce)', 0.0), ('concerned', 0.0), ('there', 0.0), ('when', 0.0), ('religions,', 0.0), ('grand', 0.0), ("'when", 0.0), ('credit,', 0.0), ('shah', 0.0), ('writes', 0.0), ('illegal', 0.0), ('at', 0.0), ('consistently', 0.0), ('passed', 0.0), ('11.3%', 0.0), ('bharatiya', 0.0), ('declared', 4.258096538021482), ('urgency', 0.0), ('guarantees', 0.0), ('ordering', 0.0), ('approach.', 0.0), ("'parliament", 0.0), ('depend', 0.0), ('say', 0.0), ('hard-won', 0.0), ('august', 0.0), ('invalid', 0.0), ('leave', 0.0), ('pathetic', 0.0), ('–', 0.0), ('equally,', 0.0), ('his', 0.0), ('court.', 0.0), ('braved', 0.0), ('essentially', 0.0), ('only', 0.0), ('well.', 0.0), ('rights', 0.0), ("'if", 0.0), ('malaise,', 0.0), ('why', 0.0), ('practice', 0.0), ('consummate', 0.0), ("'yet", 0.0), ('present', 0.0), ('every', 0.0), ('had', 0.0), ('diversity', 0.0), ('everywhere.', 0.0), ('protecting', 0.0), ('don’t', 0.0), ('integral', 0.0), ('victims', 0.0), ('courts', 0.0), ('bano,', 0.0), ('woman.', 0.0), ('1986.', 0.0), ('recent', 0.0), ('after', 0.0), ("personal.']", 0.0), ('sync', 0.0), ('did', 0.0), ('halala', 0.0), ('society', 0.0), ('observed', 0.0), ('maintenance', 0.0), ('generation', 0.0), ('includes', 0.0), ('won.', 0.0), ('boards.', 0.0), ('justice', 0.0), ('out', 0.0), ("['a", 4.258096538021482), ('70', 0.0), ('upon', 0.0), ('government', 0.0), ('wants', 0.0), ('andolan', 0.0), ('majority', 4.258096538021482), ('is', 0.0), ('remind', 0.0), ('as', 0.0), ('today’s', 0.0), ('performed', 0.0), ('31', 0.0), ('much', 0.0), ('subvert', 0.0), ('coming', 0.0), ('push', 0.0), ('1950,', 0.0), ('little', 0.0), ('by', 0.0), ('rulings', 0.0), ('lawyer,', 0.0), ('ruling', 2.6486586255873816), ('basic', 0.0), ('since', 0.0), ('ostracism', 0.0), ('been', 0.0), ('rajiv', 0.0), ('exactly', 0.0), ('but', 0.0), ('muslim', 0.0), ('cannot', 0.0), ('practices', 0.0), ('day.', 0.0), ('made', 0.0), ('their', 0.0), ('179', 0.0), ('issues', 0.0), ('if', 0.0), ('proof', 0.0), ('listen', 0.0), ('her', 0.0), ('historic', 0.0), ('about', 0.0), ('‘an', 0.0), ('they', 0.0), ('grant', 0.0), ('women.', 0.0), ('years', 0.0), ('that,', 0.0), ('bench', 0.0), ('is.', 0.0), ('unconstitutional', 4.258096538021482), ('mahila', 0.0), ('all', 0.0), ('on,', 0.0), ("'the", 0.0), ('long', 0.0), ('views', 0.0), ('process', 0.0), ('law-making', 0.0), ('heinous' ...

# %%
array_tf_idf=[]
for i in range(len(tfidf_representation)):
    for j in range(len(tfidf_representation[i])):
        array_tf_idf.append(tfidf_representation[i][j])
    
print(array_tf_idf)
# Out:
# [('', 0.0), ('or', 0.0), ('principles', 0.0), ('danial', 0.0), ('journey', 0.0), ('constitutional', 0.0), ('demand', 0.0), ('human', 0.0), ('iddat', 0.0), ('five', 0.0), ('(protection', 0.0), ('celebrate', 0.0), ('43', 0.0), ('man', 0.0), ('on', 0.0), ('expressed', 0.0), ('would', 0.0), ('2015', 0.0), ('desired.', 0.0), ('misused', 0.0), ('dowry', 0.0), ('48.5%', 0.0), ('longer.', 0.0), ('ongoing', 0.0), ("'and", 0.0), ('it’s', 0.0), ('independence,', 0.0), ('must', 0.0), ('afflicted', 0.0), ('bano’s', 0.0), ("'yet,", 0.0), ('an', 0.0), ('intervening', 0.0), ('seeking', 0.0), ('woman', 0.0), ("'india", 0.0), ('all-time', 0.0), ('rs', 0.0), ('one', 0.0), ('collective', 0.0), ('undoubtedly', 0.0), ('the', 1.3136575588550417), ('abuse', 0.0), ('nikaah', 0.0), ('‘put', 0.0), ('part', 0.0), ('has,', 0.0), ('wife', 0.0), ('dignity', 0.0), ('court', 2.1786549963416464), ('this', 0.0), ('to', 0.0), ('ignore', 0.0), ('within', 0.0), ('our', 0.0), ('changed', 0.0), ('talaq', 3.5649493574615367), ('protect', 0.0), ('ban', 0.0), ('instant', 4.258096538021482), ('we', 0.0), ('crowned', 0.0), ('ask', 0.0), ('idea', 0.0), ('for', 0.0), ('starting', 0.0), ('are', 0.0), ('years,', 0.0), ('be', 0.0), ('judgment.', 0.0), ('decision', 0.0), ('delude', 0.0), ('instead', 0.0), ('before', 0.0), ('vacation', 0.0), ('chose', 0.0), ('victory,', 0.0), ('outside', 0.0), ('pay', 0.0), ('per', 0.0), ('period', 0.0), ('doors', 0.0), ('couples', 0.0), ('marriage', 0.0), ('religion’', 0.0), ('divorced', 0.0), ('new', 0.0), ('politics’', 0.0), ('my', 0.0), ('where', 0.0), ('place', 0.0), ('neat', 0.0), ('prerogative', 0.0), ('separated', 0.0), ('judgment', 0.0), ('divorce)', 0.0), ('concerned', 0.0), ('there', 0.0), ('when', 0.0), ('religions,', 0.0), ('grand', 0.0), ("'when", 0.0), ('credit,', 0.0), ('shah', 0.0), ('writes', 0.0), ('illegal', 0.0), ('at', 0.0), ('consistently', 0.0), ('passed', 0.0), ('11.3%', 0.0), ('bharatiya', 0.0), ('declared', 4.258096538021482), ('urgency', 0.0), ('guarantees', 0.0), ('ordering', 0.0), ('approach.', 0.0), ("'parliament", 0.0), ('depend', 0.0), ('say', 0.0), ('hard-won', 0.0), ('august', 0.0), ('invalid', 0.0), ('leave', 0.0), ('pathetic', 0.0), ('–', 0.0), ('equally,', 0.0), ('his', 0.0), ('court.', 0.0), ('braved', 0.0), ('essentially', 0.0), ('only', 0.0), ('well.', 0.0), ('rights', 0.0), ("'if", 0.0), ('malaise,', 0.0), ('why', 0.0), ('practice', 0.0), ('consummate', 0.0), ("'yet", 0.0), ('present', 0.0), ('every', 0.0), ('had', 0.0), ('diversity', 0.0), ('everywhere.', 0.0), ('protecting', 0.0), ('don’t', 0.0), ('integral', 0.0), ('victims', 0.0), ('courts', 0.0), ('bano,', 0.0), ('woman.', 0.0), ('1986.', 0.0), ('recent', 0.0), ('after', 0.0), ("personal.']", 0.0), ('sync', 0.0), ('did', 0.0), ('halala', 0.0), ('society', 0.0), ('observed', 0.0), ('maintenance', 0.0), ('generation', 0.0), ('includes', 0.0), ('won.', 0.0), ('boards.', 0.0), ('justice', 0.0), ('out', 0.0), ("['a", 4.258096538021482), ('70', 0.0), ('upon', 0.0), ('government', 0.0), ('wants', 0.0), ('andolan', 0.0), ('majority', 4.258096538021482), ('is', 0.0), ('remind', 0.0), ('as', 0.0), ('today’s', 0.0), ('performed', 0.0), ('31', 0.0), ('much', 0.0), ('subvert', 0.0), ('coming', 0.0), ('push', 0.0), ('1950,', 0.0), ('little', 0.0), ('by', 0.0), ('rulings', 0.0), ('lawyer,', 0.0), ('ruling', 2.6486586255873816), ('basic', 0.0), ('since', 0.0), ('ostracism', 0.0), ('been', 0.0), ('rajiv', 0.0), ('exactly', 0.0), ('but', 0.0), ('muslim', 0.0), ('cannot', 0.0), ('practices', 0.0), ('day.', 0.0), ('made', 0.0), ('their', 0.0), ('179', 0.0), ('issues', 0.0), ('if', 0.0), ('proof', 0.0), ('listen', 0.0), ('her', 0.0), ('historic', 0.0), ('about', 0.0), ('‘an', 0.0), ('they', 0.0), ('grant', 0.0), ('women.', 0.0), ('years', 0.0), ('that,', 0.0), ('bench', 0.0), ('is.', 0.0), ('unconstitutional', 4.258096538021482), ('mahila', 0.0), ('all', 0.0), ('on,', 0.0), ("'the", 0.0), ('long', 0.0), ('views', 0.0), ('process', 0.0), ('law-making', 0.0), ('heinous', ...

# %%
a_tf_idf=[]
sorted_tf_idf=[]
alpha_tf_idf=[]
a_tf_idf.append(sorted(array_tf_idf, key=lambda tup:(-tup[1], tup[0])))
print(len(a_tf_idf[0]))
for i in range(len(a_tf_idf[0])):
    if a_tf_idf[0][i][0].isalpha():
        alpha_tf_idf.append(a_tf_idf[0][i])
alpha_tf_idf=list(set(alpha_tf_idf))
alpha_tf_idf
# Out:
# 10322
# [('she', 0.0),
#  ('over', 4.258096538021482),
#  ('was', 2.6486586255873816),
#  ('pay', 4.258096538021482),
#  ('per', 4.258096538021482),
#  ('response', 0.0),
#  ('about', 4.258096538021482),
#  ('six', 0.0),
#  ('law', 0.0),
#  ('appointed', 0.0),
#  ('section', 0.0),
#  ('shah', 3.159484249353372),
#  ('themselves', 0.0),
#  ('act', 6.0359839534249895),
#  ('period', 4.258096538021482),
#  ('lack', 0.0),
#  ('muslim', 2.466337068793427),
#  ('that', 1.9555114450274362),
#  ('knock', 0.0),
#  ('most', 0.0),
#  ('upon', 0.0),
#  ('ruling', 0.0),
#  ('arbitrary', 4.258096538021482),
#  ('on', 2.466337068793427),
#  ('representation', 0.0),
#  ('victims', 4.258096538021482),
#  ('approach', 0.0),
#  ('while', 3.5649493574615367),
#  ('rajiv', 4.258096538021482),
#  ('divorce', 4.258096538021482),
#  ('silence', 4.258096538021482),
#  ('did', 0.0),
#  ('in', 3.3109686897009083),
#  ('push', 4.258096538021482),
#  ('halala', 0.0),
#  ('crowned', 4.258096538021482),
#  ('since', 0.0),
#  ('nobody', 0.0),
#  ('observed', 4.258096538021482),
#  ('idea', 0.0),
#  ('constitution', 0.0),
#  ('criticism', 4.258096538021482),
#  ('only', 0.0),
#  ('they', 0.0),
#  ('vacation', 4.258096538021482),
#  ('comprise', 4.258096538021482),
#  ('noise', 4.258096538021482),
#  ('subvert', 4.258096538021482),
#  ('relatively', 4.258096538021482),
#  ('not', 2.8718021769015913),
#  ('woman', 0.0),
#  ('waqf', 4.258096538021482),
#  ('marry', 0.0),
#  ('abstract', 0.0),
#  ('women', 0.0),
#  ('writes', 0.0),
#  ('afflicted', 4.258096538021482),
#  ('my', 0.0),
#  ('dignity', 4.258096538021482),
#  ('moment', 0.0),
#  ('wants', 4.258096538021482),
#  ('grand', 4.258096538021482),
#  ('remarries', 0.0),
#  ('justice', 3.159484249353372),
#  ('court', 2.1786549963416464),
#  ('of', 0.0),
#  ('rain', 4.258096538021482),
#  ('ordering', 4.258096538021482),
#  ('but', 0.0),
#  ('or', 0.0),
#  ('that', 0.0),
#  ('man', 4.258096538021482),
#  ('adopt', 4.258096538021482),
#  ('where', 0.0),
#  ('social', 4.258096538021482),
#  ('couples', 7.209584147903136),
#  ('relatives', 0.0),
#  ('piecemeal', 0.0),
#  ('bano', 4.258096538021482),
#  ('decision', 0.0),
#  ('delude', 0.0),
#  ('celebrate', 4.258096538021482),
#  ('integral', 4.258096538021482),
#  ('country', 4.258096538021482),
#  ('why', 0.0),
#  ('a', 1.4855078157817008),
#  ('after', 0.0),
#  ('own', 4.258096538021482),
#  ('iddat', 4.258096538021482),
#  ('ourselves', 4.258096538021482),
#  ('at', 6.0359839534249895),
#  ('function', 4.258096538021482),
#  ('every', 4.258096538021482),
#  ('couples', 0.0),
#  ('andolan', 4.258096538021482),
#  ('a', 2.5151833699905493),
#  ('ignore', 4.258096538021482),
#  ('principles', 4.258096538021482),
#  ('sync', 0.0),
#  ('when', 3.5649493574615367),
#  ('moment', 3.159484249353372),
#  ('itself', 0.0),
#  ('religion', 0.0),
#  ('bench', 0.0),
#  ('other', 3.5649493574615367),
#  ('be', 2.1786549963416464),
#  ('is', 3.489359549729299),
#  ('christian', 4.258096538021482),
#  ('act', 0.0),
#  ('sense', 0.0),
#  ('declared', 0.0),
#  ('gender', 2.8718021769015913),
#  ('asked', 3.5649493574615367),
#  ('where', 3.5649493574615367),
#  ('on', 0.0),
#  ('if', 4.258096538021482),
#  ('demand', 3.159484249353372),
#  ('the', 0.0),
#  ('by', 2.6486586255873816),
#  ('outside', 0.0),
#  ('divorced', 2.8718021769015913),
#  ('all', 0.0),
#  ('glory', 4.258096538021482),
#  ('minority', 3.5649493574615367),
#  ('up', 0.0),
#  ('equality', 4.258096538021482),
#  ('in', 1.9555114450274362),
#  ('appealed', 0.0),
#  ('brought', 0.0),
#  ('overturn', 0.0),
#  ('rights', 0.0),
#  ('changed', 4.258096538021482),
#  ('gave', 4.258096538021482),
#  ('august', 4.258096538021482),
#  ('nikaah', 0.0),
#  ('it', 2.3121863889661687),
#  ('ruled', 4.258096538021482),
#  ('and', 1.6190392084062235),
#  ('exactly', 0.0),
#  ('an', 2.1786549963416464),
#  ('includes', 4.258096538021482),
#  ('passed', 0.0),
#  ('misused', 0.0),
#  ('who', 0.0),
#  ('fact', 4.258096538021482),
#  ('before', 4.258096538021482),
#  ('starting', 3.5649493574615367),
#  ('petitioners', 4.258096538021482),
#  ('by', 4.484568884179056),
#  ('human', 4.258096538021482),
#  ('friends', 4.258096538021482),
#  ('a', 3.8763404137179416),
#  ('when', 0.0),
#  ('practices', 0.0),
#  ('ban', 0.0),
#  ('depend', 4.258096538021482),
#  ('natural', 0.0),
#  ('comes', 0.0),
#  ('pathetic', 0.0),
#  ('present', 6.0359839534249895),
#  ('other', 0.0),
#  ('urgency', 0.0),
#  ('danial', 4.258096538021482),
#  ('journey', 4.258096538021482),
#  ('views', 4.258096538021482),
#  ('act', 3.5649493574615367),
#  ('aid', 4.258096538021482),
#  ('propriety', 4.258096538021482),
#  ('take', 4.258096538021482),
#  ('its', 3.5649493574615367),
#  ('for', 2.1786549963416464),
#  ('batted', 4.258096538021482),
#  ('demand', 0.0),
#  ('benches', 0.0),
#  ('braved', 0.0),
#  ('have', 2.6486586255873816),
#  ('while', 0.0),
#  ('limit', 0.0),
#  ('conjunction', 4.258096538021482),
#  ('of', 1.4855078157817008),
#  ('demonstrated', 0.0),
#  ('month', 4.258096538021482),
#  ('in', 0.0),
#  ('invalid', 4.258096538021482),
#  ('leave', 4.258096538021482),
#  ('basic', 0.0),
#  ('since', 3.159484249353372),
#  ('little', 0.0),
#  ('issues', 0.0),
#  ('courts', 7.209584147903136),
#  ('marriage', 0.0),
#  ('rule', 0.0),
#  ('section', 7.209584147903136),
#  ('to', 1.3677247801253174),
#  ('found', 4.258096538021482),
#  ('seeking', 4.258096538021482),
#  ('gandhi', 0.0),
#  ('illegal', 0.0),
#  ('suffer', 0.0),
#  ('rs', 0.0),
#  ('they', 3.5649493574615367),
#  ('illegal', 4.258096538021482),
#  ('starting', 0.0),
#  ('high', 3.5649493574615367),
#  ('response', 4.258096538021482),
#  ('to', 2.3157593552511524),
#  ('such', 0.0),
#  ('six', 4.258096538021482),
#  ('within', 4.258096538021482),
#  ('needed', 0.0),
#  ('during', 4.258096538021482),
#  ('law', 4.258096538021482),
#  ('justice', 0.0),
#  ('day', 4.258096538021482),
#  ('be', 0.0),
#  ('will', 0.0),
#  ('protect', 0.0),
#  ('both', 0.0),
#  ('knock', 4.258096538021482),
#  ('upon', 4.258096538021482),
#  ('its', 0.0),
#  ('arbitrary', 0.0),
#  ('the', 2.7568578961149415),
#  ('consistently', 4.258096538021482),
#  ('approach', 4.258096538021482),
#  ('victims', 0.0),
#  ('was', 4.484568884179056),
#  ('women', 3.6887835644686966),
#  ('ongoing', 4.258096538021482),
#  ('did', 4.258096538021482),
#  ('halala', 4.258096538021482),
#  ('bhandare', 0.0),
#  ('make', 3.5649493574615367),
#  ('neat', 0.0),
#  ('little', 3.5649493574615367),
#  ('observed', 0.0),
#  ('idea', 4.258096538021482),
#  ('criticism', 0.0),
#  ('of', 3.8763404137179416),
#  ('an', 0.0),
#  ('intervening', 0.0),
#  ('vacation', 0.0),
#  ('comprise', 0.0),
#  ('years', 0.0),
#  ('noise', 0.0),
#  ('ruling', 2.6486586255873816),
#  ('subvert', 0.0),
#  ('three', 3.5649493574615367),
#  ('doors', 0.0),
#  ('we', 0.0),
#  ('decades', 0.0),
#  ('high', 0.0),
#  ('waqf', 0.0),
#  ('abstract', 4.258096538021482),
#  ('performed', 4.258096538021482),
#  ('to', 3.5689928950345973),
#  ('and', 2.7412716709290033),
#  ('writes', 4.258096538021482),
#  ('afflicted', 0.0),
#  ('diversity', 0.0),
#  ('process', 4.258096538021482),
#  ('five', 4.258096538021482),
#  ('wants', 0.0),
#  ('separated', 4.258096538021482),
#  ('like', 4.258096538021482),
#  ('any', 6.0359839534249895),
#  ('will', 3.5649493574615367),
#  ('as', 6.0359839534249895),
#  ('bharatiya', 0.0),
#  ('much', 4.258096538021482),
#  ('protecting', 0.0),
#  ('man', 0.0),
#  ('for', 0.0),
#  ('heinous', 4.258096538021482),
#  ('the', 3.134773625138307),
#  ('not', 0.0),
#  ('piecemeal', 4.258096538021482),
#  ('had', 3.159484249353372),
#  ('undoubtedly', 3.5649493574615367),
#  ('bano', 0.0),
#  ('which', 2.6486586255873816),
#  ('minority', 0.0),
#  ('majority', 4.258096538021482),
#  ('celebrate', 0.0),
#  ('say', 0.0),
#  ('integral', 0.0),
#  ('under', 0.0),
#  ('is', 0.0),
#  ('of', 2.5151833699905493),
#  ('own', 0.0),
#  ('but', 2.8718021769015913),
#  ('historic', 0.0),
#  ('iddat', 0.0),
#  ('years', 3.5649493574615367),
#  ('two', 0.0),
#  ('good', 4.258096538021482),
#  ('polygamy', 0.0),
#  ('judges', 7.209584147903136),
#  ('part', 0.0),
#  ('diversity', 3.5649493574615367),
#  ('there', 0.0),
#  ('principles', 0.0),
#  ('sync', 4.258096538021482),
#  ('battle', 4.258096538021482),
#  ('charity', 4.258096538021482),
#  ('religion', 4.258096538021482),
#  ('judgment', 0.0),
#  ('present', 3.5649493574615367),
#  ('collective', 0.0),
#  ('this', 3.159484249353372),
#  ('christian', 0.0),
#  ('prerogative', 4.258096538021482),
#  ('her', 3.5649493574615367),
#  ('instant', 0.0),
#  ('all', 4.258096538021482),
#  ('had', 0.0),
#  ('against', 4.258096538021482),
#  ('undoubtedly', 0.0),
#  ('too', 4.258096538021482),
#  ('equality', 0.0),
#  ('overturn', 4.258096538021482),
#  ('rights', 4.862383758946843),
#  ('read', 4.258096538021482),
#  ('amendments', 0.0),
#  ('the', 1.3136575588550417),
#  ('nikaah', 4.258096538021482),
#  ('court', 3.6887835644686966),
#  ('essentially', 0.0),
#  ('exactly', 4.258096538021482),
#  ('earlier', 0.0),
#  ('frame', 3.5649493574615367),
#  ('includes', 0.0),
#  ('misused', 4.258096538021482),
#  ('fact', 0.0),
#  ('cannot', 0.0),
#  ('polygamy', 3.5649493574615367),
#  ('petitioners', 0.0),
#  ('mahila', 0.0),
#  ('unconstitutional', 0.0),
#  ('by', 0.0),
#  ('abuse', 4.258096538021482),
#  ('human', 0.0),
#  ('expressed', 0.0),
#  ('divorced', 0.0),
#  ('must', 3.159484249353372),
#  ('adult', 0.0),
#  ('and', 0.0),
#  ('friends', 0.0),
#  ('has', 0.0),
#  ('new', 0.0),
#  ('proof', 0.0),
#  ('chose', 4.258096538021482),
#  ('practices', 4.258096538021482),
#  ('him', 4.258096538021482),
#  ('ban', 4.258096538021482),
#  ('coming', 4.258096538021482),
#  ('needed', 3.5649493574615367),
#  ('natural', 4.258096538021482),
#  ('would', 4.258096538021482),
#  ('judgment', 3.159484249353372),
#  ('depend', 0.0),
#  ('parliament', 0.0),
#  ('as', 0.0),
#  ('it', 4.852382769575544),
#  ('views', 0.0),
#  ('her', 0.0),
#  ('hero', 4.258096538021482),
#  ('propriety', 0.0),
#  ('take', 0.0),
#  ('remind', 4.258096538021482),
#  ('muslim', 4.175871654338072),
#  ('where', 6.0359839534249895),
#  ('batted', 0.0),
#  ('benches', 4.258096538021482),
#  ('place', 4.258096538021482),
#  ('judges', 0.0),
#  ('recent', 3.5649493574615367),
#  ('month', 0.0),
#  ('in', 4.103860349165711),
#  ('invalid', 0.0),
#  ('wife', 4.258096538021482),
#  ('instead', 4.258096538021482),
#  ('leave', 0.0),
#  ('make', 0.0),
#  ('lot', 0.0),
#  ('issues', 4.258096538021482),
#  ('long', 4.258096538021482),
#  ('marriage', 4.258096538021482),
#  ('is', 2.0608719606852626),
#  ('suffer', 4.258096538021482),
#  ('seeking', 0.0),
#  ('frame', 0.0),
#  ('guarantees', 4.258096538021482),
#  ('practice', 4.258096538021482),
#  ('time', 3.5649493574615367),
#  ('only', 6.0359839534249895),
#  ('constitutional', 0.0),
#  ('we', 3.159484249353372),
#  ('three', 0.0),
#  ('cannot', 3.5649493574615367),
#  ('his', 0.0),
#  ('maintenance', 0.0),
#  ('must', 0.0),
#  ('have', 4.484568884179056),
#  ('such', 4.258096538021482),
#  ('dowry', 4.258096538021482),
#  ('government', 0.0),
#  ('within', 0.0),
#  ('during', 0.0),
#  ('society', 4.258096538021482),
#  ('effect', 0.0),
#  ('day', 0.0),
#  ('nevertheless', 4.258096538021482),
#  ('from', 0.0),
#  ('as', 3.5649493574615367),
#  ('ostracism', 4.258096538021482),
#  ('it', 3.9148718654071497),
#  ('protect', 4.258096538021482),
#  ('right', 4.258096538021482),
#  ('both', 4.258096538021482),
#  ('generation', 0.0),
#  ('mother', 0.0),
#  ('grant', 4.258096538021482),
#  ('concerned', 4.258096538021482),
#  ('with', 0.0),
#  ('consistently', 0.0),
#  ('are', 4.258096538021482),
#  ('was', 0.0),
#  ('recent', 0.0),
#  ('ongoing', 0.0),
#  ('one', 0.0),
#  ('bhandare', 4.258096538021482),
#  ('neat', 4.258096538021482),
#  ('aside', 0.0),
#  ('under', 3.5649493574615367),
#  ('talaq', 0.0),
#  ('passing', 4.258096538021482),
#  ('rulings', 4.258096538021482),
#  ('listen', 0.0),
#  ('intervening', 4.258096538021482),
#  ('supreme', 0.0),
#  ('consummate', 0.0),
#  ('doors', 4.258096538021482),
#  ('decades', 4.258096538021482),
#  ('out', 0.0),
#  ('she', 4.258096538021482),
#  ('made', 7.209584147903136),
#  ('over', 0.0),
#  ('performed', 0.0),
#  ('there', 3.5649493574615367),
#  ('pay', 0.0),
#  ('per', 0.0),
#  ('process', 0.0),
#  ('about', 0.0),
#  ('five', 0.0),
#  ('separated', 0.0),
#  ('what', 3.5649493574615367),
#  ('like', 0.0),
#  ('present', 0.0),
#  ('appointed', 4.258096538021482),
#  ('took', 3.5649493574615367),
#  ('from', 3.5649493574615367),
#  ('courts', 0.0),
#  ('bharatiya', 4.258096538021482),
#  ('this', 0.0),
#  ('themselves', 4.258096538021482),
#  ('much', 0.0),
#  ('protecting', 4.258096538021482),
#  ('lack', 4.258096538021482),
#  ('period', 0.0),
#  ('most', 4.258096538021482),
#  ('heinous', 0.0),
#  ('not', 4.862383758946843),
#  ('a', 3.117504957112),
#  ('majority', 0.0),
#  ('one', 3.5649493574615367),
#  ('rajiv', 0.0),
#  ('divorce', 0.0),
#  ('silence', 0.0),
#  ('push', 0.0),
#  ('say', 4.258096538021482),
#  ('ask', 0.0),
#  ('crowned', 0.0),
#  ('talaq', 3.5649493574615367),
#  ('is', 4.324971222065634),
#  ('nobody', 4.258096538021482),
#  ('been', 3.159484249353372),
#  ('constitution', 4.258096538021482),
#  ('historic', 4.258096538021482),
#  ('supreme', 1.9555114450274362),
#  ('two', 4.258096538021482),
#  ('our', 0.0),
#  ('at', 3.5649493574615367),
#  ('good', 0.0),
#  ('part', 4.258096538021482),
#  ('relatively', 0.0),
#  ('woman', 4.258096538021482),
#  ('marry', 4.258096538021482),
#  ('battle', 0.0),
#  ('which', 0.0),
#  ('charity', 0.0),
#  ('my', 4.258096538021482),
#  ('dignity', 0.0),
#  ('any', 3.5649493574615367),
#  ('grand', 0.0),
#  ('remarries', 4.258096538021482),
#  ('collective', 4.258096538021482),
#  ('prerogative', 0.0),
#  ('rain', 0.0),
#  ('ordering', 0.0),
#  ('instant', 4.258096538021482),
#  ('adopt', 0.0),
#  ('representation', 3.5649493574615367),
#  ('social', 0.0),
#  ('made', 0.0),
#  ('their', 0.0),
#  ('relatives', 4.258096538021482),
#  ('against', 0.0),
#  ('a', 0.0),
#  ('too', 0.0),
#  ('to', 2.87032403108688),
#  ('decision', 4.258096538021482),
#  ('delude', 4.258096538021482),
#  ('read', 0.0),
#  ('amendments', 4.258096538021482),
#  ('country', 0.0),
#  ('been', 0.0),
#  ('essentially', 4.258096538021482),
#  ('why', 4.258096538021482),
#  ('earlier', 4.258096538021482),
#  ('or', 5.349471848816218),
#  ('time', 0.0),
#  ('only', 3.5649493574615367),
#  ('gender', 0.0),
#  ('ourselves', 0.0),
#  ('our', 3.5649493574615367),
#  ('the', 2.2242155919966744),
#  ('function', 0.0),
#  ('mahila', 4.258096538021482),
#  ('unconstitutional', 4.258096538021482),
#  ('every', 0.0),
#  ('proof', 4.258096538021482),
#  ('abuse', 0.0),
#  ('expressed', 4.258096538021482),
#  ('new', 4.258096538021482),
#  ('maintenance', 3.5649493574615367),
#  ('adult', 4.258096538021482),
#  ('andolan', 0.0),
#  ('ignore', 0.0),
#  ('chose', 0.0),
#  ('government', 3.5649493574615367),
#  ('him', 0.0),
#  ('coming', 0.0),
#  ('rights', 2.8718021769015913),
#  ('would', 0.0),
#  ('itself', 4.258096538021482),
#  ('any', 0.0),
#  ('bench', 4.258096538021482),
#  ('it', 0.0),
#  ('of', 3.544858924199398),
#  ('sense', 4.258096538021482),
#  ('of', 3.117504957112),
#  ('declared', 4.258096538021482),
#  ('or', 3.159484249353372),
#  ('hero', 0.0),
#  ('remind', 0.0),
#  ('that', 3.3109686897009083),
#  ('muslim', 0.0),
#  ('if', 0.0),
#  ('place', 0.0),
#  ('their', 3.159484249353372),
#  ('outside', 4.258096538021482),
#  ('must', 5.349471848816218),
#  ('to', 3.263793930376987),
#  ('has', 2.8718021769015913),
#  ('glory', 0.0),
#  ('wife', 0.0),
#  ('instead', 0.0),
#  ('appealed', 4.258096538021482),
#  ('brought', 4.258096538021482),
#  ('lot', 4.258096538021482),
#  ('changed', 0.0),
#  ('parliament', 2.6486586255873816),
#  ('gave', 0.0),
#  ('long', 0.0),
#  ('august', 0.0),
#  ('after', 3.5649493574615367),
#  ('triple', 3.5649493574615367),
#  ('ruled', 0.0),
#  ('supreme', 3.3109686897009083),
#  ('guarantees', 0.0),
#  ('appropriate', 3.5649493574615367),
#  ('practice', 0.0),
#  ('constitutional', 4.258096538021482),
#  ('passed', 4.258096538021482),
#  ('his', 4.258096538021482),
#  ('the', 3.4279078380319765),
#  ('before', 0.0),
#  ('have', 0.0),
#  ('women', 2.1786549963416464),
#  ('dowry', 0.0),
#  ('what', 0.0),
#  ('effect', 4.258096538021482),
#  ('society', 0.0),
#  ('comes', 4.258096538021482),
#  ('nevertheless', 0.0),
#  ('pathetic', 4.258096538021482),
#  ('took', 0.0),
#  ('ostracism', 0.0),
#  ('court', 0.0),
#  ('urgency', 4.258096538021482),
#  ('right', 0.0),
#  ('shah', 0.0),
#  ('danial', 0.0),
#  ('generation', 4.258096538021482),
#  ('journey', 0.0),
#  ('aid', 0.0),
#  ('mother', 4.258096538021482),
#  ('grant', 0.0),
#  ('concerned', 0.0),
#  ('asked', 0.0),
#  ('are', 0.0),
#  ('braved', 4.258096538021482),
#  ('to', 0.0),
#  ('limit', 4.258096538021482),
#  ('demonstrated', 4.258096538021482),
#  ('conjunction', 0.0),
#  ('up', 3.5649493574615367),
#  ('ask', 3.5649493574615367),
#  ('basic', 4.258096538021482),
#  ('aside', 4.258096538021482),
#  ('passing', 0.0),
#  ('rulings', 0.0),
#  ('listen', 4.258096538021482),
#  ('rule', 4.258096538021482),
#  ('triple', 0.0),
#  ('gandhi', 4.258096538021482),
#  ('found', 0.0),
#  ('appropriate', 0.0),
#  ('rs', 4.258096538021482),
#  ('consummate', 4.258096538021482),
#  ('at', 0.0),
#  ('who', 3.159484249353372),
#  ('out', 4.258096538021482),
#  ('with', 2.8718021769015913)]

# %%
from nltk.corpus import stopwords
stops_tf_idf =  set(stopwords.words('english'))
all_seperate_tf_idf = []
stops_tf_idf.update("when","who","how")
for w in alpha_tf_idf:
    if w[0] not in stops_tf_idf:
            all_seperate_tf_idf.append(w)
sepe=sorted(all_seperate_tf_idf, key=lambda tup:(-tup[1], tup[0]))
top_tf_idf=[]
for i in range(100):
    top_tf_idf.append(sepe[i])
top_tf_idf=[(t[0], int(t[1]*3)) for t in top_tf_idf]
print(top_tf_idf)
# Out:
# [('couples', 21), ('courts', 21), ('judges', 21), ('made', 21), ('section', 21), ('act', 18), ('present', 18), ('must', 16), ('rights', 14), ('abstract', 12), ('abuse', 12), ('adopt', 12), ('adult', 12), ('afflicted', 12), ('aid', 12), ('amendments', 12), ('andolan', 12), ('appealed', 12), ('appointed', 12), ('approach', 12), ('arbitrary', 12), ('aside', 12), ('august', 12), ('ban', 12), ('bano', 12), ('basic', 12), ('batted', 12), ('battle', 12), ('bench', 12), ('benches', 12), ('bhandare', 12), ('bharatiya', 12), ('braved', 12), ('brought', 12), ('celebrate', 12), ('changed', 12), ('charity', 12), ('chose', 12), ('christian', 12), ('collective', 12), ('comes', 12), ('coming', 12), ('comprise', 12), ('concerned', 12), ('conjunction', 12), ('consistently', 12), ('constitution', 12), ('constitutional', 12), ('consummate', 12), ('country', 12), ('criticism', 12), ('crowned', 12), ('danial', 12), ('day', 12), ('decades', 12), ('decision', 12), ('declared', 12), ('delude', 12), ('demonstrated', 12), ('depend', 12), ('dignity', 12), ('divorce', 12), ('doors', 12), ('dowry', 12), ('earlier', 12), ('effect', 12), ('equality', 12), ('essentially', 12), ('every', 12), ('exactly', 12), ('expressed', 12), ('fact', 12), ('five', 12), ('found', 12), ('friends', 12), ('function', 12), ('gandhi', 12), ('gave', 12), ('generation', 12), ('glory', 12), ('good', 12), ('grand', 12), ('grant', 12), ('guarantees', 12), ('halala', 12), ('heinous', 12), ('hero', 12), ('historic', 12), ('human', 12), ('iddat', 12), ('idea', 12), ('ignore', 12), ('illegal', 12), ('includes', 12), ('instant', 12), ('instead', 12), ('integral', 12), ('intervening', 12), ('invalid', 12), ('issues', 12)]

# %%
data= str(data)
data = data.lower()
words = word_tokenize(data)
print(words)
# Out:
# ['[', "'a", 'majority', 'ruling', 'of', 'the', 'supreme', 'court', 'has', 'declared', 'instant', 'triple', 'talaq', 'unconstitutional', 'and', 'unislamic', '.', 'it', 'has', 'asked', 'parliament', 'to', '‘', 'put', 'aside', 'politics', '’', 'and', 'frame', 'an', 'appropriate', 'law', '.', 'starting', 'now', ',', 'the', 'practice', 'is', 'invalid', 'and', 'it', 'is', 'up', 'to', 'parliament', 'to', 'frame', 'an', 'appropriate', 'law', 'that', 'will', 'make', 'it', 'illegal', 'as', 'well', '.', 'this', 'is', 'a', 'ruling', 'that', 'is', 'both', 'in', 'sync', 'with', 'constitutional', 'propriety', '–', 'law-making', 'is', 'parliament', '’', 's', 'prerogative', '–', 'and', 'the', 'principles', 'of', 'natural', 'justice', '.', "'", ',', "'parliament", 'has', 'not', 'exactly', 'crowned', 'itself', 'with', 'glory', 'when', 'it', 'comes', 'to', 'gender', 'justice', 'for', 'minority', 'women', ',', 'starting', 'from', 'the', 'ironically-named', 'muslim', 'women', '(', 'protection', 'of', 'rights', 'under', 'divorce', ')', 'act', 'passed', 'by', 'the', 'rajiv', 'gandhi', 'government', 'in', '1986.', 'the', 'act', 'was', 'brought', 'in', 'to', 'overturn', 'and', 'subvert', 'an', 'earlier', 'supreme', 'court', 'ruling', 'to', 'grant', 'maintenance', 'to', 'shah', 'bano', ',', 'a', '62-year-old', 'muslim', 'mother', 'of', 'five', 'who', 'had', 'been', 'divorced', 'by', 'her', 'husband', '.', 'what', 'parliament', 'essentially', 'did', 'was', 'to', 'limit', 'divorced', 'muslim', 'women', 'to', 'maintenance', 'only', 'for', 'the', 'iddat', 'period', '(', 'roughly', 'three', 'months', ')', 'after', 'which', 'they', 'would', 'have', 'to', 'depend', 'on', 'the', 'charity', 'of', 'relatives', 'or', 'waqf', 'boards', '.', "'", ',', "'yet", 'in', 'the', '31', 'years', 'since', 'the', 'passing', 'of', 'that', 'act', ',', 'the', 'supreme', 'court', 'has', ',', 'to', 'its', 'credit', ',', 'consistently', 'batted', 'for', 'the', 'rights', 'of', 'minority', 'women', '.', 'when', 'danial', 'latifi', ',', 'incidentally', ',', 'shah', 'bano', '’', 's', 'lawyer', ',', 'appealed', 'against', 'a', 'high', 'court', 'ruling', 'ordering', 'him', 'to', 'pay', 'rs', '179', 'a', 'month', 'to', 'his', 'divorced', 'wife', 'for', '43', 'years', ',', 'the', 'supreme', 'court', 'ruled', 'that', 'the', 'muslim', 'women', 'act', 'had', 'to', 'be', 'read', 'in', 'conjunction', 'with', 'the', 'constitution', 'that', 'guarantees', 'dignity', 'and', 'equality', 'to', 'women', '.', "'", ',', "'when", 'a', 'two-judge', 'bench', 'in', '2015', 'observed', 'that', 'polygamy', 'was', 'not', '‘', 'an', 'integral', 'part', 'of', 'religion', '’', 'or', 'gave', 'muslim', 'women', 'the', 'right', 'to', 'adopt', 'or', 'asked', 'the', 'government', 'to', 'make', 'amendments', 'to', 'an', 'arbitrary', 'rule', 'under', 'which', 'christian', 'couples', 'seeking', 'a', 'divorce', 'had', 'to', 'be', 'separated', 'for', 'two', 'years', ',', 'instead', 'of', 'the', 'one', 'by', 'couples', 'from', 'other', 'religions', ',', 'it', 'was', 'in', 'effect', 'coming', 'to', 'the', 'aid', 'of', 'the', 'rights', 'of', 'women', '.', "'", ',', "'yet", ',', '70', 'years', 'after', 'independence', ',', 'gender', 'justice', 'can', 'not', 'be', 'an', 'abstract', 'idea', 'to', 'which', 'we', 'have', 'a', 'piecemeal', 'approach', '.', 'the', 'supreme', 'court', '’', 's', 'own', 'recent', 'rulings', 'on', ',', 'say', '498a', ',', 'a', 'section', 'that', 'is', 'undoubtedly', 'misused', 'but', 'nevertheless', 'a', 'section', 'that', 'is', 'needed', 'to', 'protect', 'victims', 'of', 'the', 'ongoing', 'dowry', 'malaise', ',', 'leave', 'a', 'lot', 'to', 'be', 'desired', '.', 'there', 'was', 'criticism', 'too', 'of', 'a', 'recent', 'ruling', 'on', '‘', 'love', 'jihad', '’', 'or', 'the', 'decision', 'to', 'marry', 'a', 'man', 'outside', 'her', 'religion', 'by', 'an', 'adult', 'woman', '.', "'", ',', "'certainly", ',', 'we', 'must', 'ask', 'why', 'the', 'supreme', 'court', 'took', 'up', 'triple', 'talaq', 'with', 'such' ...

# %%
from nltk.corpus import stopwords
stops =  set(stopwords.words('english'))
print(stops)
# Out:
# {'there', 'or', 'when', 'mightn', 'with', 'whom', 'all', 'being', 'at', 'against', 'ma', 'such', 'very', 'o', 'who', 'any', 's', 'further', 'yourself', 'themselves', 'each', 'more', 'himself', 'do', 'were', 'on', 'because', 'up', 'needn', 'ain', 'herself', 'his', 'from', 'was', 'through', 'no', 'only', 'she', 'why', 'wouldn', 'it', 'had', 're', 'doesn', 'most', 'those', 'don', 'can', 'how', 'your', 'an', 'i', 'under', 'now', 'does', 'hers', 'while', 'having', 'above', 'after', 'just', 'y', 'what', 'off', 'did', 'some', 'couldn', 'which', 'than', 'nor', 'in', 'itself', 'he', 'the', 'out', 'won', 'so', 'below', 'will', 'hadn', 'this', 'is', 'over', 'yourselves', 'to', 'our', 'as', 'here', 'not', 'wasn', 'doing', 'both', 'that', 'during', 'shouldn', 'we', 'shan', 'weren', 'by', 'have', 'a', 'few', 'own', 'for', 'are', 'down', 'again', 'you', 'be', 'aren', 'mustn', 'before', 'been', 'then', 'll', 'didn', 'theirs', 'of', 'should', 'but', 'these', 'myself', 'am', 'isn', 'yours', 'their', 'd', 'hasn', 'him', 't', 'haven', 'ours', 'if', 'm', 'once', 'between', 'too', 'her', 'my', 've', 'about', 'ourselves', 'where', 'them', 'until', 'has', 'and', 'into', 'they', 'its', 'same', 'me', 'other'}

# %%
all_seperate = []
stops.update(".","?" ,"(",")" , "[" , "]" , " ' " , " , " ," '' " ," {" ," } " , "``" ,"..." , ""''":" ,"'``':" ,"when","who","how")
for w in words:
    if w not in stops:
        if w.isalpha():
            all_seperate.append(w)
print(all_seperate)
# Out:
# ['majority', 'ruling', 'supreme', 'court', 'declared', 'instant', 'triple', 'talaq', 'unconstitutional', 'unislamic', 'asked', 'parliament', 'put', 'aside', 'politics', 'frame', 'appropriate', 'law', 'starting', 'practice', 'invalid', 'parliament', 'frame', 'appropriate', 'law', 'make', 'illegal', 'well', 'ruling', 'sync', 'constitutional', 'propriety', 'parliament', 'prerogative', 'principles', 'natural', 'justice', 'exactly', 'crowned', 'glory', 'comes', 'gender', 'justice', 'minority', 'women', 'starting', 'muslim', 'women', 'protection', 'rights', 'divorce', 'act', 'passed', 'rajiv', 'gandhi', 'government', 'act', 'brought', 'overturn', 'subvert', 'earlier', 'supreme', 'court', 'ruling', 'grant', 'maintenance', 'shah', 'bano', 'muslim', 'mother', 'five', 'divorced', 'husband', 'parliament', 'essentially', 'limit', 'divorced', 'muslim', 'women', 'maintenance', 'iddat', 'period', 'roughly', 'three', 'months', 'would', 'depend', 'charity', 'relatives', 'waqf', 'boards', 'years', 'since', 'passing', 'act', 'supreme', 'court', 'credit', 'consistently', 'batted', 'rights', 'minority', 'women', 'danial', 'latifi', 'incidentally', 'shah', 'bano', 'lawyer', 'appealed', 'high', 'court', 'ruling', 'ordering', 'pay', 'rs', 'month', 'divorced', 'wife', 'years', 'supreme', 'court', 'ruled', 'muslim', 'women', 'act', 'read', 'conjunction', 'constitution', 'guarantees', 'dignity', 'equality', 'women', 'bench', 'observed', 'polygamy', 'integral', 'part', 'religion', 'gave', 'muslim', 'women', 'right', 'adopt', 'asked', 'government', 'make', 'amendments', 'arbitrary', 'rule', 'christian', 'couples', 'seeking', 'divorce', 'separated', 'two', 'years', 'instead', 'one', 'couples', 'religions', 'effect', 'coming', 'aid', 'rights', 'women', 'years', 'independence', 'gender', 'justice', 'abstract', 'idea', 'piecemeal', 'approach', 'supreme', 'court', 'recent', 'rulings', 'say', 'section', 'undoubtedly', 'misused', 'nevertheless', 'section', 'needed', 'protect', 'victims', 'ongoing', 'dowry', 'malaise', 'leave', 'lot', 'desired', 'criticism', 'recent', 'ruling', 'love', 'jihad', 'decision', 'marry', 'man', 'outside', 'religion', 'adult', 'woman', 'must', 'ask', 'supreme', 'court', 'took', 'triple', 'talaq', 'sense', 'urgency', 'vacation', 'time', 'chose', 'ignore', 'demand', 'ban', 'heinous', 'practices', 'like', 'nikaah', 'halala', 'process', 'muslim', 'woman', 'must', 'consummate', 'intervening', 'marriage', 'remarries', 'divorced', 'husband', 'polygamy', 'petitioners', 'certainly', 'must', 'concerned', 'lack', 'gender', 'diversity', 'within', 'august', 'benches', 'supreme', 'court', 'much', 'made', 'representation', 'women', 'parliament', 'comprise', 'high', 'pathetic', 'per', 'cent', 'relatively', 'little', 'noise', 'made', 'fact', 'judges', 'appointed', 'supreme', 'court', 'since', 'six', 'women', 'present', 'one', 'supreme', 'court', 'judges', 'present', 'woman', 'justice', 'includes', 'diversity', 'representation', 'neat', 'little', 'slogan', 'must', 'performed', 'demonstrated', 'every', 'day', 'everywhere', 'nobody', 'wants', 'rain', 'grand', 'moment', 'gender', 'rights', 'present', 'supreme', 'court', 'judgment', 'undoubtedly', 'equally', 'good', 'time', 'push', 'ask', 'society', 'afflicted', 'women', 'approach', 'courts', 'demand', 'basic', 'human', 'rights', 'courts', 'remind', 'parliament', 'function', 'protecting', 'rights', 'country', 'citizens', 'hero', 'found', 'historic', 'moment', 'collective', 'women', 'petitioners', 'took', 'upon', 'knock', 'doors', 'supreme', 'court', 'demand', 'listen', 'plight', 'friends', 'bharatiya', 'mahila', 'muslim', 'andolan', 'braved', 'ostracism', 'abuse', 'long', 'journey', 'judgment', 'day', 'changed', 'country', 'since', 'three', 'decades', 'shah', 'bano', 'judgment', 'proof', 'needed', 'today', 'judgment', 'response', 'new', 'generation', 'women', 'suffer', 'silence', 'longer', 'place', 'take', 'moment', 'celebrate', 'victory', 'let', 'delude', 'battle', 'bhandare', 'writes', 'social', 'issues',  ...

# %%
new_freq2=[]
most_common3=[]
for i in range(len(all_seperate)-1):
    new_freq2.append(" ".join((all_seperate[i],all_seperate[i+1])))
counter=Counter(new_freq2)
most_common2= counter.most_common(100)
for i in range(len(most_common2)):
    if most_common2[i][1] > 2:
        most_common3.append((most_common2[i]))
print(most_common3)
# Out:
# [('supreme court', 11), ('muslim women', 4), ('shah bano', 3)]

# %%
all_words=[]
import sys
class PorterStemmer:

    def __init__(self):
        self.b = ""  # buffer for word to be stemmed
        self.k = 0
        self.k0 = 0
        self.j = 0   # j is a general offset into the string

    def cons(self, i):
        if self.b[i] == 'a' or self.b[i] == 'e' or self.b[i] == 'i' or self.b[i] == 'o' or self.b[i] == 'u':
            return 0
        if self.b[i] == 'y':
            if i == self.k0:
                return 1
            else:
                return (not self.cons(i - 1))
        return 1

    def m(self):
        n = 0
        i = self.k0
        while 1:
            if i > self.j:
                return n
            if not self.cons(i):
                break
            i = i + 1
        i = i + 1
        while 1:
            while 1:
                if i > self.j:
                    return n
                if self.cons(i):
                    break
                i = i + 1
            i = i + 1
            n = n + 1
            while 1:
                if i > self.j:
                    return n
                if not self.cons(i):
                    break
                i = i + 1
            i = i + 1

    def vowelinstem(self):
        for i in range(self.k0, self.j + 1):
            if not self.cons(i):
                return 1
        return 0

    def doublec(self, j):
        if j < (self.k0 + 1):
            return 0
        if (self.b[j] != self.b[j-1]):
            return 0
        return self.cons(j)

    def cvc(self, i):
        if i < (self.k0 + 2) or not self.cons(i) or self.cons(i-1) or not self.cons(i-2):
            return 0
        ch = self.b[i]
        if ch == 'w' or ch == 'x' or ch == 'y':
            return 0
        return 1

    def ends(self, s):
        length = len(s)
        if s[length - 1] != self.b[self.k]: # tiny speed-up
            return 0
        if length > (self.k - self.k0 + 1):
            return 0
        if self.b[self.k-length+1:self.k+1] != s:
            return 0
        self.j = self.k - length
        return 1

    def setto(self, s):
        length = len(s)
        self.b = self.b[:self.j+1] + s + self.b[self.j+length+1:]
        self.k = self.j + length

    def r(self, s):
        if self.m() > 0:
            self.setto(s)

    def step1ab(self):
        if self.b[self.k] == 's':
            if self.ends("sses"):
                self.k = self.k - 2
            elif self.ends("ies"):
                self.setto("i")
            elif self.b[self.k - 1] != 's':
                self.k = self.k - 1
        if self.ends("eed"):
            if self.m() > 0:
                self.k = self.k - 1
        elif (self.ends("ed") or self.ends("ing")) and self.vowelinstem():
            self.k = self.j
            if self.ends("at"):   self.setto("ate")
            elif self.ends("bl"): self.setto("ble")
            elif self.ends("iz"): self.setto("ize")
            elif self.doublec(self.k):
                self.k = self.k - 1
                ch = self.b[self.k]
                if ch == 'l' or ch == 's' or ch == 'z':
                    self.k = self.k + 1
            elif (self.m() == 1 and self.cvc(self.k)):
                self.setto("e")

    def step1c(self):
        if (self.ends("y") and self.vowelinstem()):
            self.b = self.b[:self.k] + 'i' + self.b[self.k+1:]

    def step2(self):
        if self.b[self.k - 1] == 'a':
            if self.ends("ational"):   self.r("ate")
            elif self.ends("tional"):  self.r("tion")
        elif self.b[self.k - 1] == 'c':
            if self.ends("enci"):      self.r("ence")
            elif self.ends("anci"):    self.r("ance")
        elif self.b[self.k - 1] == 'e':
            if self.ends("izer"):      self.r("ize")
        elif self.b[self.k - 1] == 'l':
            if self.ends("bli"):       self.r("ble") 
            elif self.ends("alli"):    self.r("al")
            elif self.ends("entli"):   self.r("ent")
            elif self.ends("eli"):     self.r("e")
            elif self.ends("ousli"):   self.r("ous")
        elif self.b[self.k - 1] == 'o':
            if self.ends("ization"):   self.r("ize")
            elif self.ends("ation"):   self.r("ate")
            elif self.ends("ator"):    self.r("ate")
        elif self.b[self.k - 1] == 's':
            if self.ends("alism"):     self.r("al")
            elif self.ends("iveness"): self.r("ive")
            elif self.ends("fulness"): self.r("ful")
            elif self.ends("ousness"): self.r("ous")
        elif self.b[self.k - 1] == 't':
            if self.ends("aliti"):     self.r("al")
            elif self.ends("iviti"):   self.r("ive")
            elif self.ends("biliti"):  self.r("ble")
        elif self.b[self.k - 1] == 'g':
            if self.ends("logi"):      self.r("log")

    def step3(self):
        if self.b[self.k] == 'e':
            if self.ends("icate"):     self.r("ic")
            elif self.ends("ative"):   self.r("")
            elif self.ends("alize"):   self.r("al")
        elif self.b[self.k] == 'i':
            if self.ends("iciti"):     self.r("ic")
        elif self.b[self.k] == 'l':
            if self.ends("ical"):      self.r("ic")
            elif self.ends("ful"):     self.r("")
        elif self.b[self.k] == 's':
            if self.ends("ness"):      self.r("")

    def step4(self):
        if self.b[self.k - 1] == 'a':
            if self.ends("al"): pass
            else: return
        elif self.b[self.k - 1] == 'c':
            if self.ends("ance"): pass
            elif self.ends("ence"): pass
            else: return
        elif self.b[self.k - 1] == 'e':
            if self.ends("er"): pass
            else: return
        elif self.b[self.k - 1] == 'i':
            if self.ends("ic"): pass
            else: return
        elif self.b[self.k - 1] == 'l':
            if self.ends("able"): pass
            elif self.ends("ible"): pass
            else: return
        elif self.b[self.k - 1] == 'n':
            if self.ends("ant"): pass
            elif self.ends("ement"): pass
            elif self.ends("ment"): pass
            elif self.ends("ent"): pass
            else: return
        elif self.b[self.k - 1] == 'o':
            if self.ends("ion") and (self.b[self.j] == 's' or self.b[self.j] == 't'): pass
            elif self.ends("ou"): pass
            else: return
        elif self.b[self.k - 1] == 's':
            if self.ends("ism"): pass
            else: return
        elif self.b[self.k - 1] == 't':
            if self.ends("ate"): pass
            elif self.ends("iti"): pass
            else: return
        elif self.b[self.k - 1] == 'u':
            if self.ends("ous"): pass
            else: return
        elif self.b[self.k - 1] == 'v':
            if self.ends("ive"): pass
            else: return
        elif self.b[self.k - 1] == 'z':
            if self.ends("ize"): pass
            else: return
        else:
            return
        if self.m() > 1:
            self.k = self.j

    def step5(self):
        self.j = self.k
        if self.b[self.k] == 'e':
            a = self.m()
            if a > 1 or (a == 1 and not self.cvc(self.k-1)):
                self.k = self.k - 1
        if self.b[self.k] == 'l' and self.doublec(self.k) and self.m() > 1:
            self.k = self.k -1

    def stem(self, p, i, j):
        self.b = p
        self.k = j
        self.k0 = i
        if self.k <= self.k0 + 1:
            return self.b
        self.step1ab()
        self.step1c()
        self.step2()
        self.step3()
        self.step4()
        self.step5()
        return self.b[self.k0:self.k+1]
    

if __name__ == '__main__':
    for i in all_seperate:
        if i.isalpha():
            p = PorterStemmer()
            word=i
            output = p.stem(word, 0,len(word)-1)
            all_words.append(output)
            
print(all_words)
# Out:
# ['major', 'rule', 'suprem', 'court', 'declar', 'instant', 'tripl', 'talaq', 'unconstitut', 'unislam', 'ask', 'parliament', 'put', 'asid', 'polit', 'frame', 'appropri', 'law', 'start', 'practic', 'invalid', 'parliament', 'frame', 'appropri', 'law', 'make', 'illeg', 'well', 'rule', 'sync', 'constitut', 'proprieti', 'parliament', 'prerog', 'principl', 'natur', 'justic', 'exactli', 'crown', 'glori', 'come', 'gender', 'justic', 'minor', 'women', 'start', 'muslim', 'women', 'protect', 'right', 'divorc', 'act', 'pass', 'rajiv', 'gandhi', 'govern', 'act', 'brought', 'overturn', 'subvert', 'earlier', 'suprem', 'court', 'rule', 'grant', 'mainten', 'shah', 'bano', 'muslim', 'mother', 'five', 'divorc', 'husband', 'parliament', 'essenti', 'limit', 'divorc', 'muslim', 'women', 'mainten', 'iddat', 'period', 'roughli', 'three', 'month', 'would', 'depend', 'chariti', 'rel', 'waqf', 'board', 'year', 'sinc', 'pass', 'act', 'suprem', 'court', 'credit', 'consist', 'bat', 'right', 'minor', 'women', 'danial', 'latifi', 'incident', 'shah', 'bano', 'lawyer', 'appeal', 'high', 'court', 'rule', 'order', 'pai', 'rs', 'month', 'divorc', 'wife', 'year', 'suprem', 'court', 'rule', 'muslim', 'women', 'act', 'read', 'conjunct', 'constitut', 'guarante', 'digniti', 'equal', 'women', 'bench', 'observ', 'polygami', 'integr', 'part', 'religion', 'gave', 'muslim', 'women', 'right', 'adopt', 'ask', 'govern', 'make', 'amend', 'arbitrari', 'rule', 'christian', 'coupl', 'seek', 'divorc', 'separ', 'two', 'year', 'instead', 'on', 'coupl', 'religion', 'effect', 'come', 'aid', 'right', 'women', 'year', 'independ', 'gender', 'justic', 'abstract', 'idea', 'piecem', 'approach', 'suprem', 'court', 'recent', 'rule', 'sai', 'section', 'undoubtedli', 'misus', 'nevertheless', 'section', 'need', 'protect', 'victim', 'ongo', 'dowri', 'malais', 'leav', 'lot', 'desir', 'critic', 'recent', 'rule', 'love', 'jihad', 'decis', 'marri', 'man', 'outsid', 'religion', 'adult', 'woman', 'must', 'ask', 'suprem', 'court', 'took', 'tripl', 'talaq', 'sens', 'urgenc', 'vacat', 'time', 'chose', 'ignor', 'demand', 'ban', 'heinou', 'practic', 'like', 'nikaah', 'halala', 'process', 'muslim', 'woman', 'must', 'consumm', 'interven', 'marriag', 'remarri', 'divorc', 'husband', 'polygami', 'petition', 'certainli', 'must', 'concern', 'lack', 'gender', 'divers', 'within', 'august', 'bench', 'suprem', 'court', 'much', 'made', 'represent', 'women', 'parliament', 'compris', 'high', 'pathet', 'per', 'cent', 'rel', 'littl', 'nois', 'made', 'fact', 'judg', 'appoint', 'suprem', 'court', 'sinc', 'six', 'women', 'present', 'on', 'suprem', 'court', 'judg', 'present', 'woman', 'justic', 'includ', 'divers', 'represent', 'neat', 'littl', 'slogan', 'must', 'perform', 'demonstr', 'everi', 'dai', 'everywher', 'nobodi', 'want', 'rain', 'grand', 'moment', 'gender', 'right', 'present', 'suprem', 'court', 'judgment', 'undoubtedli', 'equal', 'good', 'time', 'push', 'ask', 'societi', 'afflict', 'women', 'approach', 'court', 'demand', 'basic', 'human', 'right', 'court', 'remind', 'parliament', 'function', 'protect', 'right', 'countri', 'citizen', 'hero', 'found', 'histor', 'moment', 'collect', 'women', 'petition', 'took', 'upon', 'knock', 'door', 'suprem', 'court', 'demand', 'listen', 'plight', 'friend', 'bharatiya', 'mahila', 'muslim', 'andolan', 'brave', 'ostrac', 'abus', 'long', 'journei', 'judgment', 'dai', 'chang', 'countri', 'sinc', 'three', 'decad', 'shah', 'bano', 'judgment', 'proof', 'need', 'todai', 'judgment', 'respons', 'new', 'gener', 'women', 'suffer', 'silenc', 'longer', 'place', 'take', 'moment', 'celebr', 'victori', 'let', 'delud', 'battl', 'bhandar', 'write', 'social', 'issu', 'gender', 'view', 'express', 'person']

# %%
counter = Counter(all_words)
most_com =counter.most_common(50)
print(most_com)
# Out:
# [('court', 14), ('women', 13), ('suprem', 11), ('rule', 8), ('muslim', 7), ('right', 7), ('parliament', 6), ('divorc', 6), ('gender', 5), ('ask', 4), ('justic', 4), ('act', 4), ('year', 4), ('must', 4), ('judgment', 4), ('protect', 3), ('shah', 3), ('bano', 3), ('sinc', 3), ('religion', 3), ('woman', 3), ('demand', 3), ('present', 3), ('moment', 3), ('tripl', 2), ('talaq', 2), ('frame', 2), ('appropri', 2), ('law', 2), ('start', 2), ('practic', 2), ('make', 2), ('constitut', 2), ('come', 2), ('minor', 2), ('pass', 2), ('govern', 2), ('mainten', 2), ('husband', 2), ('three', 2), ('month', 2), ('rel', 2), ('high', 2), ('equal', 2), ('bench', 2), ('polygami', 2), ('coupl', 2), ('on', 2), ('approach', 2), ('recent', 2)]

# %%
for i in most_common3:
    most_com.insert(0,i)
print(most_com)
# Out:
# [('shah bano', 3), ('muslim women', 4), ('supreme court', 11), ('court', 14), ('women', 13), ('suprem', 11), ('rule', 8), ('muslim', 7), ('right', 7), ('parliament', 6), ('divorc', 6), ('gender', 5), ('ask', 4), ('justic', 4), ('act', 4), ('year', 4), ('must', 4), ('judgment', 4), ('protect', 3), ('shah', 3), ('bano', 3), ('sinc', 3), ('religion', 3), ('woman', 3), ('demand', 3), ('present', 3), ('moment', 3), ('tripl', 2), ('talaq', 2), ('frame', 2), ('appropri', 2), ('law', 2), ('start', 2), ('practic', 2), ('make', 2), ('constitut', 2), ('come', 2), ('minor', 2), ('pass', 2), ('govern', 2), ('mainten', 2), ('husband', 2), ('three', 2), ('month', 2), ('rel', 2), ('high', 2), ('equal', 2), ('bench', 2), ('polygami', 2), ('coupl', 2), ('on', 2), ('approach', 2), ('recent', 2)]

# %%
# -*- coding: utf-8 -*-
from copy import copy
from math import sin, cos, ceil
from pygame import transform, font, mask, Surface, Rect, SRCALPHA, draw
from pygame.sprite import Group, Sprite, collide_mask
from random import randint, choice
import colorsys
import math
import os
import pygame
import simplejson


TAG_PADDING = 5
TAG_CLOUD_PADDING = 5 # Margins added to the whole image
STEP_SIZE = 2 # relative to base step size of each spiral function
RADIUS = 1
ECCENTRICITY = 1.5

LOWER_START = 0.45
UPPER_START = 0.55

#FONT_DIR = os.path.join(os.path.dirname(os.path.abspath(__file__)), 'fonts')
DEFAULT_FONT = 'Droid Sans'
DEFAULT_PALETTE = 'default'
FONT_CACHE = simplejson.load(open('fonts.json'), 'r')

pygame.init()
convsurf = Surface((2 * TAG_PADDING, 2 * TAG_PADDING))
convsurf.fill((255, 0, 255))
convsurf.set_colorkey((255, 0, 255))
draw.circle(convsurf, (0, 0, 0), (TAG_PADDING, TAG_PADDING), TAG_PADDING)
CONVMASK = mask.from_surface(convsurf)

LAYOUT_HORIZONTAL = 0
LAYOUT_VERTICAL = 1
LAYOUT_MOST_HORIZONTAL = 2
LAYOUT_MOST_VERTICAL = 3
LAYOUT_MIX = 4

LAYOUTS = (
           LAYOUT_HORIZONTAL,
           LAYOUT_VERTICAL,
           LAYOUT_MOST_HORIZONTAL,
           LAYOUT_MOST_VERTICAL,
           LAYOUT_MIX
           )

LAST_COLLISON_HIT = None

FONTS = {}

def get_font(font, size):
    name = font['ttf']
    if (name, size) not in FONTS:
        FONTS[name, size] = pygame.font.Font(name, size)
    return FONTS[name, size]

class Tag(Sprite):
    """
    Font tag sprite. Blit the font to a surface to correct the font padding
    """
    def __init__(self, tag, initial_position, fontname=DEFAULT_FONT):
        Sprite.__init__(self)
        self.tag = copy(tag)
        self.rotation = 0
        
        self.font_spec = load_font(fontname)
        self.font = get_font(self.font_spec, self.tag['size'])
        fonter = self.font.render(tag['tag'], True, tag['color'])
        frect = fonter.get_bounding_rect()
        frect.x = -frect.x
        frect.y = -frect.y
        self.fontoffset = (-frect.x, -frect.y)
        font_sf = Surface((frect.width, frect.height), pygame.SRCALPHA, 32)
        font_sf.blit(fonter, frect)
        self.image = font_sf
        self.rect = font_sf.get_rect()
        self.rect.width += TAG_PADDING
        self.rect.height += TAG_PADDING
        self.rect.x = initial_position[0]
        self.rect.y = initial_position[1]
        self._update_mask()

    def _update_mask(self):
        self.mask = mask.from_surface(self.image)
        self.mask = self.mask.convolve(CONVMASK, None, (TAG_PADDING, TAG_PADDING))

    def flip(self):
        angle = 90 if self.rotation == 0 else - 90
        self.rotate(angle)

    def rotate(self, angle):
        pos = (self.rect.x, self.rect.y)
        self.image = transform.rotate(self.image, angle)
        self.rect = self.image.get_rect()
        self.rect.x, self.rect.y = pos
        self._update_mask()

    def update_fontsize(self):
        self.font = get_font(self.font_spec, self.tag['size'])
        
def load_font(name):
    for font in FONT_CACHE:
        if font['name'] == name:
            return font
    raise AttributeError('Invalid font name. Should be one of %s' % 
                         ", ".join([f['name'] for f in FONT_CACHE]))

def defscale(count, mincount, maxcount, minsize, maxsize):
    if maxcount == mincount:
        return int((maxsize - minsize) / 2.0 + minsize)
    return int(minsize + (maxsize - minsize) * 
               (count * 1.0 / (maxcount - mincount)) ** 0.8)

def make_tags(wordcounts, minsize=3, maxsize=36, colors=None, scalef=defscale):
    """
    sizes and colors tags 
    wordcounts is a list of tuples(tags, count). (e.g. how often the
    word appears in a text)
    the tags are assigned sizes between minsize and maxsize, the function used
    is determined by scalef (default: square root)
    color is either chosen from colors (list of rgb tuples) if provided or random
    """
    counts = [tag[1] for tag in wordcounts]

    if not len(counts):
        return []

    maxcount = max(counts)
    mincount = min(counts)
    tags = []
    for word_count in wordcounts:
        color = choice(colors) if colors else (randint(10, 220), randint(10, 220),
                                               randint(10, 220))
        tags.append({'color': color, 'size': scalef(word_count[1], mincount,
                                                    maxcount, minsize, maxsize),
                     'tag': word_count[0]})
    return tags

def _do_collide(sprite, group):
    """
    Use mask based collision detection
    """
    global LAST_COLLISON_HIT
    # Test if we still collide with the last hit
    if LAST_COLLISON_HIT and collide_mask(sprite, LAST_COLLISON_HIT):
        return True
    
    for sp in group:
        if collide_mask(sprite, sp):
            LAST_COLLISON_HIT = sp
            return True
    return False

def _get_tags_bounding(tag_store):
    if not len(tag_store):
        return Rect(0,0,0,0)
    rects = [tag.rect for tag in tag_store]
    return rects[0].unionall(rects[1:])

def _get_group_bounding(tag_store, sizeRect):
    if not isinstance(sizeRect, pygame.Rect):
        sizeRect = Rect(0, 0, sizeRect[0], sizeRect[1])
    if tag_store:
        rects = [tag.rect for tag in tag_store]
        union = rects[0].unionall(rects[1:])
        if sizeRect.contains(union):
            return union
    return sizeRect

def _archimedean_spiral(reverse):
    DEFAULT_STEP = 0.05 # radians
    t = 0
    r = 1
    if reverse:
        r = -1
    while True:
        t += DEFAULT_STEP * STEP_SIZE * r
        yield (ECCENTRICITY * RADIUS * t * cos(t), RADIUS * t * sin(t))

def _rectangular_spiral(reverse):
    DEFAULT_STEP = 3 # px
    directions = [(1, 0), (0, 1), (-1, 0), (0, -1)]
    if reverse:
        directions.reverse()
    direction = directions[0]

    spl = 1
    dx = dy = 0
    while True:
        for step in range(spl * 2):
            if step == spl:
                direction = directions[(spl - 1) % 4]
            dx += direction[0] * STEP_SIZE * DEFAULT_STEP
            dy += direction[1] * STEP_SIZE * DEFAULT_STEP
            yield dx, dy
        spl += 1

def _search_place(current_tag, tag_store, canvas, spiral, ratio):
    """
    Start a spiral search with random direction.
    Resize the canvas if the spiral exceeds the bounding rectangle
    """

    reverse = choice((0, 1))
    start_x = current_tag.rect.x
    start_y = current_tag.rect.y
    min_dist = None
    opt_x = opt_y = 0
    
    current_bounding = _get_tags_bounding(tag_store)
    cx = current_bounding.w / 2.0
    cy = current_bounding.h / 2.0

    for dx, dy in spiral(reverse):
        current_tag.rect.x = start_x + dx
        current_tag.rect.y = start_y + dy
        if not _do_collide(current_tag, tag_store):
            if canvas.contains(current_tag.rect):
                tag_store.add(current_tag)
                return
            else:
                # get the distance from center
                current_dist = (abs(cx - current_tag.rect.x) ** 2 + 
                                abs(cy - current_tag.rect.y) ** 2) ** 0.5
                if not min_dist or current_dist < min_dist:
                    opt_x = current_tag.rect.x
                    opt_y = current_tag.rect.y 
                    min_dist = current_dist

                # only add tag if the spiral covered the canvas boundaries
                if abs(dx) > canvas.width / 2.0 and abs(dy) > canvas.height / 2.0:
                    current_tag.rect.x = opt_x                    
                    current_tag.rect.y = opt_y                    
                    tag_store.add(current_tag)

                    new_bounding = current_bounding.union(current_tag.rect)

                    delta_x = delta_y = 0.0
                    if new_bounding.w > canvas.width:
                        delta_x = new_bounding.w - canvas.width

                        canvas.width = new_bounding.w
                        delta_y = ratio * new_bounding.w - canvas.height
                        canvas.height = ratio * new_bounding.w

                    if new_bounding.h > canvas.height:
                        delta_y = new_bounding.h - canvas.height

                        canvas.height = new_bounding.h
                        canvas.width = new_bounding.h / ratio
                        delta_x = canvas.width - canvas.width

                    # realign
                    for tag in tag_store:
                        tag.rect.x += delta_x / 2.0
                        tag.rect.y += delta_y / 2.0


                    canvas = _get_tags_bounding(tag_store)

                    return

def _draw_cloud(
        tag_list,
        layout=LAYOUT_MIX,
        size=(500,500),
        fontname=DEFAULT_FONT,
        rectangular=False):

    # sort the tags by size and word length
    tag_list.sort(key=lambda tag: len(tag['tag']))
    #tag_list.sort(key=lambda t: len(t['tag']))
    tag_list.sort(key=lambda tag: tag['size'])
    #tag_list.reverse()

    # create the tag space
    tag_sprites = []
    area = 0
    for tag in tag_list:
        tag_sprite = Tag(tag, (0, 0), fontname=fontname)
        area += tag_sprite.mask.count()
        tag_sprites.append(tag_sprite)

    canvas = Rect(0, 0, 0, 0)
    ratio = float(size[1]) / size[0]

    if rectangular:
        spiral = _rectangular_spiral
    else:
        spiral = _archimedean_spiral

    aligned_tags = Group()
    for tag_sprite in tag_sprites:
        angle = 0
        if layout == LAYOUT_MIX and randint(0, 2) == 0:
            angle = 90
        elif layout == LAYOUT_VERTICAL:
            angle = 90

        tag_sprite.rotate(angle)

        xpos = canvas.width - tag_sprite.rect.width
        if xpos < 0: xpos = 0
        xpos = randint(int(xpos * LOWER_START) , int(xpos * UPPER_START))
        tag_sprite.rect.x = xpos

        ypos = canvas.height - tag_sprite.rect.height
        if ypos < 0: ypos = 0
        ypos = randint(int(ypos * LOWER_START), int(ypos * UPPER_START))
        tag_sprite.rect.y = ypos

        _search_place(tag_sprite, aligned_tags, canvas, spiral, ratio)
    canvas = _get_tags_bounding(aligned_tags)

    # resize cloud
    zoom = min(float(size[0]) / canvas.w, float(size[1]) / canvas.h)
    
    for tag in aligned_tags:
        tag.rect.x *= zoom
        tag.rect.y *= zoom
        tag.rect.width *= zoom
        tag.rect.height *= zoom
        tag.tag['size'] = int(tag.tag['size'] * zoom)
        tag.update_fontsize() 

    canvas = _get_tags_bounding(aligned_tags)

    return canvas, aligned_tags

def create_tag_image(
        tags, 
        output, 
        size=(500,500), 
        background=(255, 255, 255), 
        layout=LAYOUT_MIX, 
        fontname=DEFAULT_FONT,
        rectangular=False):
    """
    Create a png tag cloud image
    """

    if not len(tags):
        return

    sizeRect, tag_store = _draw_cloud(tags,
                                      layout,
                                      size=size, 
                                      fontname=fontname,
                                      rectangular=rectangular)

    if type(output) == pygame.Surface:
        image_surface = output
    else:
        image_surface = Surface((sizeRect.w + 2*TAG_CLOUD_PADDING, sizeRect.h + 2*TAG_CLOUD_PADDING), SRCALPHA, 32)
        image_surface.fill(background)
    for tag in tag_store:
        image_surface.blit(tag.image, (tag.rect.x - sizeRect.x + TAG_CLOUD_PADDING, tag.rect.y - sizeRect.y + TAG_CLOUD_PADDING))
    pygame.image.save(image_surface, output)

def create_html_data(tags, 
        size=(500,500), 
        layout=LAYOUT_MIX, 
        fontname=DEFAULT_FONT,
        rectangular=False):
    """
    Create data structures to be used for HTML tag clouds.
    """

    if not len(tags):
        return

    sizeRect, tag_store = _draw_cloud(tags,
                                      layout,
                                      size=size, 
                                      fontname=fontname,
                                      rectangular=rectangular)

    tag_store = sorted(tag_store, key=lambda tag: tag.tag['size'])
    tag_store.reverse()
    data = {
            'css': {},
            'links': []
            }

    color_map = {}
    for color_index, tag in enumerate(tags):
        if not color_map in(tag['color']):
            color_name = "c%d" % color_index
            hslcolor = colorsys.rgb_to_hls(tag['color'][0] / 255.0, 
                                           tag['color'][1] / 255.0, 
                                           tag['color'][2] / 255.0)
            lighter = hslcolor[1] * 1.4
            if lighter > 1: lighter = 1
            light = colorsys.hls_to_rgb(hslcolor[0], lighter, hslcolor[2])
            data['css'][color_name] = ('#%02f%02f%02f' % (tag['color']), 
                                       '#%02f%02f%02f' % (light[0] * 255,
                                                          light[1] * 255,
                                                          light[2] * 255))
            color_map[tag['color']] = color_name

    for stag in tag_store:
        line_offset = 0

        line_offset = stag.font.get_linesize() - (stag.font.get_ascent() + \
                                                  abs(stag.font.get_descent()) - \
                                                  stag.rect.height) - 4

        tag = {
               'tag': stag.tag['tag'],
               'cls': color_map[stag.tag['color']],
               'top': stag.rect.y - sizeRect.y,
               'left': stag.rect.x - sizeRect.x,
               'size': int(stag.tag['size'] * 0.25),
               'height': int(stag.rect.height * 1.19) + 4,
               'width': stag.rect.width,
               'lh': line_offset
               }

        data['links'].append(tag)
        data['size'] = (sizeRect.w, sizeRect.h * 1.15)

    return data

# %%
mtr=make_tags(most_com)
chd=create_html_data(mtr)
out=_draw_cloud(mtr)
create_tag_image(mtr,'ghi.png',size=(1280, 900), background=(0, 0, 0, 255), layout=LAYOUT_MIX,fontname='Lobster')

# %%
mtr2=make_tags(top_tf_idf)
chd2=create_html_data(mtr2)
out2=_draw_cloud(mtr2)
create_tag_image(mtr2,'ghi2.png',size=(1280, 900), background=(0, 0, 0, 255), layout=LAYOUT_MIX,fontname='Lobster')
